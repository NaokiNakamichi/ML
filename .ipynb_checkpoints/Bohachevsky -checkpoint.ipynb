# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

import model_opt
import data_generate
import algo_GD

_t_max =10

# %%
data = data_generate.Data(d=2)
X,y,w_init,w = data.generate_data()

# %%
w_init
# Out:
# array([-0.13381329,  2.84701748])

# %%
f = model_opt.Bohachevsky(err = 0.1)
algo = algo_GD.GD(w=w_init,t_max=_t_max)

# %%
for i in algo:
    algo.update(model=f)
# Out:
# before[-0.13381329  2.84701748]
# 1
# 1
# [-2.87558185  6.69964298]
# after[0.15374489 2.17705318]
# before[0.15374489 2.17705318]
# 1
# 1
# [ 3.13434963 12.94804713]
# after[-0.15969007  0.88224847]
# before[-0.15969007  0.88224847]
# 1
# 1
# [-3.07827052 -1.51197352]
# after[0.14813698 1.03344582]
# before[0.14813698 1.03344582]
# 1
# 1
# [2.97342377 6.25349333]
# after[-0.1492054   0.40809649]
# before[-0.1492054   0.40809649]
# 1
# 1
# [-3.0762671  -2.94578665]
# after[0.15842131 0.70267516]
# before[0.15842131 0.70267516]
# 1
# 1
# [3.20909912 5.57255174]
# after[-0.1624886   0.14541998]
# before[-0.1624886   0.14541998]
# 1
# 1
# [-3.27457996  5.32529906]
# after[ 0.1649694  -0.38710993]
# before[ 0.1649694  -0.38710993]
# 1
# 1
# [3.1342596  3.19768219]
# after[-0.14845656 -0.70687814]
# before[-0.14845656 -0.70687814]
# 1
# 1
# [-3.27644838 -5.45772968]
# after[ 0.17918827 -0.16110518]
# before[ 0.17918827 -0.16110518]
# 1
# 1
# [ 3.23700859 -5.11624261]
# after[-0.14451258  0.35051908]

# %%
w_store = algo.wstore

# %%
w_star = w
w = w_init

# 等高線描画用
def f(x, y,w):
    return (x-w) ** 2 + (y-w) ** 2


tmpdel = np.linalg.norm(w_star-w_init) * 1
xvals = np.arange(w_star[0]-tmpdel, w_star[0]+tmpdel, 0.001)
yvals = np.arange(w_star[1]-tmpdel, w_star[1]+tmpdel, 0.01)
x1, x2 = np.meshgrid(xvals, yvals)
print(w_star[0]-tmpdel)
Z = f(x1, x2,w_star[0])
myfig = plt.figure(figsize=(12,12))

ax1 = myfig.add_subplot(2,2,1)
plt.title("Trajectory of updates")
CS = ax1.contour(x1, x2, Z, levels=10)
c = np.linspace(0, _t_max, len(w_store))
ax1.scatter(w_store.T[0],w_store.T[1],c=c,cmap = _cmap,linewidths=0.01,alpha=0.5)
ax1.plot(*w_star, 'r*', markersize=8)
CS.clabel(inline=1, fontsize=10)

ax2 = myfig.add_subplot(2,2,2)

plt.title("loss transition")
plt.xlabel('number of update steps')
plt.ylabel('loss')
ax2.plot(list(range(_t_max)),loss_transition)
# Out:
# -0.13381329356443195
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-486636480736> in <module>
#      17 ax1 = myfig.add_subplot(2,2,1)
#      18 plt.title("Trajectory of updates")
# ---> 19 CS = ax1.contour(x1, x2, Z, levels=10)
#      20 c = np.linspace(0, _t_max, len(w_store))
#      21 ax1.scatter(w_store.T[0],w_store.T[1],c=c,cmap = _cmap,linewidths=0.01,alpha=0.5)
#
# ~/.local/share/virtualenvs/ML_m1-7vQKvK6Y/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1541     def inner(ax, *args, data=None, **kwargs):
#    1542         if data is None:
# -> 1543             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1544
#    1545         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/share/virtualenvs/ML_m1-7vQKvK6Y/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    6324     def contour(self, *args, **kwargs):
#    6325         kwargs['filled'] = False
# -> 6326         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6327         self._request_autoscale_view()
#    6328         return contours
#
# ~/.local/share/virtualenvs/ML_m1-7vQKvK6Y/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     820         self._transform = kwargs.pop('transform', None)
#     821
# --> 822         kwargs = self._process_args(*args, **kwargs)
#     823         self._process_levels()
#     824
#
# ~/.local/share/virtualenvs/ML_m1-7vQKvK6Y/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1417                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1418
# -> 1419             x, y, z = self._contour_args(args, kwargs)
#    1420
#    1421             _mask = ma.getmask(z)
#
# ~/.local/share/virtualenvs/ML_m1-7vQKvK6Y/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1475             args = args[1:]
#    1476         elif Nargs <= 4:
# -> 1477             x, y, z = self._check_xyz(args[:3], kwargs)
#    1478             args = args[3:]
#    1479         else:
#
# ~/.local/share/virtualenvs/ML_m1-7vQKvK6Y/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1508             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1509         if z.shape[0] < 2 or z.shape[1] < 2:
# -> 1510             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1511                             f"but has shape {z.shape}")
#    1512         Ny, Nx = z.shape
#
# TypeError: Input z must be at least a (2, 2) shaped array, but has shape (0, 0)

# %%
np.array([1,2])
# Out:
# array([1, 2])

# %%
c = (200,200)
c[0]
# Out:
# 200

# %%
f.f_opt(w1,w2)
# Out:
# array([29757.57632165])

# %%
x = np.arange(-100, 100, 1)
y = np.arange(-100, 100, 1)
X, Y = np.meshgrid(x, y)
Z = f.f_opt(X,Y)
print(Z)
# Out:
# [[30696.50851844 30879.38409382 29720.86214546 ... 30293.08719043
#   30300.55301018 27631.72184804]
#  [29498.68454245 30754.0727978  29237.40779007 ... 30393.0719766
#   29263.47436704 27417.91162287]
#  [29124.31135529 29437.92841372 28306.3669818  ... 28935.73556457
#   27332.95182486 30910.90815588]
#  ...
#  [29269.87991507 29518.58973289 26883.3881594  ... 29078.5460664
#   30160.9213179  28606.67680403]
#  [28772.12375415 26766.90997617 29156.03115786 ... 29283.61779792
#   29295.35204704 30895.07364678]
#  [31948.06715096 31186.11659593 29258.96444698 ... 28477.10398214
#   29144.71897537 28617.67610768]]

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
x = np.arange(-10, 10, 0.1)
y = np.arange(-10, 10, 0.1)
X, Y = np.meshgrid(x, y)
Z = f.g_opt(X,Y)[1]

fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
x = np.arange(-100, 100, 1)
y = np.arange(-100, 100, 1)
X, Y = np.meshgrid(x, y)
Z = f.g_opt(X,Y)[1]

fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()
