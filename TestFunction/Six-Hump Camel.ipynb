# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import lines
import matplotlib.cm as cm
import tqdm
from tqdm.notebook import tqdm as tqdm

import model_opt
import data_generate
import algo_GD

# %%
f = model_opt.SixHumpCamel(err = 0)

x = np.arange(-2, 2, 0.1)
y = np.arange(-1, 1, 0.1)
X, Y = np.meshgrid(x, y)
Z = f.f_opt([X,Y])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)
X, Y = np.meshgrid(x, y)
Z = f.g_opt([X,Y])[1]

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
Z
# Out:
# array([[-114.   , -113.9  , -113.8  , ..., -110.3  , -110.2  , -110.1  ],
#        [ -96.544,  -96.444,  -96.344, ...,  -92.844,  -92.744,  -92.644],
#        [ -80.912,  -80.812,  -80.712, ...,  -77.212,  -77.112,  -77.012],
#        ...,
#        [  63.008,   63.108,   63.208, ...,   66.708,   66.808,   66.908],
#        [  76.912,   77.012,   77.112, ...,   80.612,   80.712,   80.812],
#        [  92.544,   92.644,   92.744, ...,   96.244,   96.344,   96.444]])
