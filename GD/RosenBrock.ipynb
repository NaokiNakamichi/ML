# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import lines
import matplotlib.cm as cm
import tqdm
from tqdm.notebook import tqdm as tqdm

import model_opt
import data_generate
import algo_GD

# %%
f = model_opt.RosenBrock(err = 0)

x = np.arange(-10, 10, 0.1)
y = np.arange(-10, 10, 0.1)
X, Y = np.meshgrid(x, y)
Z = f.f_opt([X,Y])
Z
# Out:
# array([[1210121.        , 1166734.82      , 1124564.8       , ...,
#         1083548.49999997, 1124525.59999997, 1166695.21999997],
#        [1207922.        , 1164575.62      , 1122445.        , ...,
#         1081467.69999997, 1122405.79999997, 1164536.01999997],
#        [1205725.        , 1162418.42      , 1120327.2       , ...,
#         1079388.89999997, 1120287.99999997, 1162378.81999997],
#        ...,
#        [ 815530.        ,  779984.42      ,  745576.2       , ...,
#          712242.89999998,  745536.99999998,  779944.81999998],
#        [ 813725.        ,  778219.22      ,  743850.4       , ...,
#          710556.09999998,  743811.19999998,  778179.61999998],
#        [ 811922.        ,  776456.02      ,  742126.6       , ...,
#          708871.29999998,  742087.39999998,  776416.41999998]])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)
X, Y = np.meshgrid(x, y)
Z = f.g_opt([X,Y])[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-cb8a725638a1> in <module>
#       2 y = np.arange(-2, 2, 0.1)
#       3 X, Y = np.meshgrid(x, y)
# ----> 4 Z = f.g_opt([X,Y])[1]
#
# ~/ML_m1/GD/model_opt.py in g_opt(self, w)
#     377                 tmp[i] = 100 * (-4) * w[i] * (w[i+1] - w[i] ** 2) + 2 * (w[i] - 1) + 100 * 2 * (w[i] - w[i-1] ** 2)
#     378
# --> 379         tmp = self.add_noise(tmp)
#     380
#     381         return tmp
#
# ~/ML_m1/GD/models.py in add_noise(self, w)
#      16         err = np.array(random_err) * np.random.randn(d)
#      17
# ---> 18         return w + self.err * err
#
# ValueError: operands could not be broadcast together with shapes (2,40,40) (2,)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
f.f_opt([0,0])

# %%
f.g_opt([0,1])
