# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set

# %%
d = 2
n= 10000
lr = 0.001
noise = "lognormal"
c = 1
son = loss.RosenBrock(d=d,noise_type=noise,E_var=1.75)
RV = RV_SGDAve.RVSGDByW(model_opt=son,c=1,n=n,lr=lr)

# %%
k = 5
rng = np.random.default_rng()
# w_init = rng.uniform(-c,c,size=d)
w_init = np.array([0,2])
wtr, ftr = RV.transition(k=k,w_init=w_init)
# Out:
# (1000, 5, 2)

# %%
# plot_set.w_value_2d_heatmap(f=son,w_store=wtr,_t_max=n)

# %%
core_store, selected_index, w_rv = RV.all_transition(k=k,w_init=w_init)
plot_set.w_value_2d_k_candidates_contour(f=son,core_store=core_store,selected_index=selected_index,_t_max=n)

# %%
plot_set.w_value_2d_k_candidates_contour(f=son,core_store=core_store,_t_max=n,selected_index=selected_index,trajectory=False)

# %%
pos = (np.array(wtr[:-1]) + np.array(wtr[1:]))/2
dir = np.array(wtr[:-1]) - np.array(wtr[1:])

# %%
dir
# Out:
# array([[-3.96122992e-03,  1.73588388e-01],
#        [-4.94709813e-03,  1.50366223e-01],
#        [-6.00685272e-03,  1.29993766e-01],
#        ...,
#        [ 1.32700857e-04,  1.00306068e-04],
#        [ 1.12719495e-04,  1.11221686e-04],
#        [ 1.03982015e-04,  1.15740368e-04]])
