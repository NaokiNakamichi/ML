# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from ML2_lib import DC_SGD
from ML2_lib import RV_SGDAve
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn import model_selection
from ML2_lib import models
from ML2_lib import SGDByTorch

# %%
real_data = load_iris()
x = real_data.data

scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)
# x = x.T

# %%
y = real_data.target
y = y.T

data_train, data_test, label_train, label_test = model_selection.train_test_split(x, y)
w_dim = data_train.shape[1]
class_num = 3
model = models.LinearClassification(w_num=w_dim,c_num=class_num)
# model = models.LinearClassification(4,3)
hoge = SGDByTorch.SGDTorch(lr=1)

# %%
sgd_model, stack, loss_stack, test_loss_stack,_ = hoge.learn(x=data_train, y=label_train, model=model,class_num=class_num,X_test=data_test,Y_test=label_test)
# Out:
# 1
# tensor([[1.6438, 0.3284, 1.2743, 0.7907]])
# 2
# step : 0
# [[13  0  0]
#  [ 4  0  9]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.87        13
#            1       0.00      0.00      0.00        13
#            2       0.57      1.00      0.73        12
#
#     accuracy                           0.66        38
#    macro avg       0.45      0.67      0.53        38
# weighted avg       0.44      0.66      0.53        38
#
# 正解率 : 0.6578947368421053
# 1
# tensor([[-0.9007,  1.7096, -1.2834, -1.1838]])
# 2
# 1
# tensor([[ 0.6745, -0.5924,  1.0469,  1.1856]])
# 2
# 1
# tensor([[1.6438, 1.2492, 1.3311, 1.7121]])
# 2
# 1
# tensor([[-0.9007,  0.7888, -1.2834, -1.3154]])
# 2
# 1
# tensor([[-1.3854,  0.3284, -1.2266, -1.3154]])
# 2
# 1
# tensor([[ 1.5227, -0.1320,  1.2175,  1.1856]])
# 2
# 1
# tensor([[-0.1737, -0.1320,  0.2512,  0.0009]])
# 2
# 1
# tensor([[1.0380, 0.0982, 1.0469, 1.5805]])
# 2
# 1
# tensor([[-1.0218,  0.7888, -1.2266, -1.0522]])
# 2
# 1
# tensor([[ 0.7957, -0.1320,  0.8196,  1.0539]])
# 2
# step : 10
# [[13  0  0]
#  [ 0  7  6]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.54      0.70        13
#            2       0.67      1.00      0.80        12
#
#     accuracy                           0.84        38
#    macro avg       0.89      0.85      0.83        38
# weighted avg       0.89      0.84      0.83        38
#
# 正解率 : 0.8421052631578947
# 1
# tensor([[ 0.1898, -1.9736,  0.7059,  0.3958]])
# 2
# 1
# tensor([[-1.0218, -2.4339, -0.1466, -0.2624]])
# 2
# 1
# tensor([[-1.6277, -1.7434, -1.3971, -1.1838]])
# 2
# 1
# tensor([[ 0.9168, -0.3622,  0.4786,  0.1325]])
# 2
# 1
# tensor([[-0.1737, -0.5924,  0.1944,  0.1325]])
# 2
# 1
# tensor([[0.6745, 0.3284, 0.4217, 0.3958]])
# 2
# 1
# tensor([[-0.1737, -0.5924,  0.4217,  0.1325]])
# 2
# 1
# tensor([[0.1898, 0.7888, 0.4217, 0.5274]])
# 2
# 1
# tensor([[-0.9007,  0.5586, -1.1697, -0.9205]])
# 2
# 1
# tensor([[ 0.7957, -0.1320,  0.9901,  0.7907]])
# 2
# step : 20
# [[13  0  0]
#  [ 5  4  4]
#  [ 0  3  9]]
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.84        13
#            1       0.57      0.31      0.40        13
#            2       0.69      0.75      0.72        12
#
#     accuracy                           0.68        38
#    macro avg       0.66      0.69      0.65        38
# weighted avg       0.66      0.68      0.65        38
#
# 正解率 : 0.6842105263157895
# 1
# tensor([[ 0.1898, -1.9736,  0.1375, -0.2624]])
# 2
# 1
# tensor([[-0.5372,  0.7888, -1.2834, -1.0522]])
# 2
# 1
# tensor([[-0.5372,  0.7888, -1.1697, -1.3154]])
# 2
# 1
# tensor([[2.2497, 1.7096, 1.6722, 1.3172]])
# 2
# 1
# tensor([[-0.5372,  1.4794, -1.2834, -1.3154]])
# 2
# 1
# tensor([[ 0.5533, -0.8226,  0.6491,  0.7907]])
# 2
# 1
# tensor([[ 0.3110, -0.5924,  0.1375,  0.1325]])
# 2
# 1
# tensor([[-0.2948, -0.8226,  0.2512,  0.1325]])
# 2
# 1
# tensor([[-5.2506e-02, -1.0528e+00,  1.3755e-01,  8.7755e-04]])
# 2
# 1
# tensor([[1.0380, 0.5586, 1.1038, 1.1856]])
# 2
# step : 30
# [[13  0  0]
#  [ 2  9  2]
#  [ 0  3  9]]
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93        13
#            1       0.75      0.69      0.72        13
#            2       0.82      0.75      0.78        12
#
#     accuracy                           0.82        38
#    macro avg       0.81      0.81      0.81        38
# weighted avg       0.81      0.82      0.81        38
#
# 正解率 : 0.8157894736842105
# 1
# tensor([[-0.0525, -0.5924,  0.7628,  1.5805]])
# 2
# 1
# tensor([[-1.5065,  0.3284, -1.3402, -1.3154]])
# 2
# 1
# tensor([[ 0.3110, -0.5924,  0.5354,  0.0009]])
# 2
# 1
# tensor([[-1.0218, -0.1320, -1.2266, -1.3154]])
# 2
# 1
# tensor([[ 1.6438, -0.1320,  1.1606,  0.5274]])
# 2
# 1
# tensor([[-1.7489,  0.3284, -1.3971, -1.3154]])
# 2
# 1
# tensor([[ 2.2497, -0.1320,  1.3311,  1.4488]])
# 2
# 1
# tensor([[-1.1430, -0.1320, -1.3402, -1.3154]])
# 2
# 1
# tensor([[ 2.1285, -0.1320,  1.6153,  1.1856]])
# 2
# 1
# tensor([[-1.2642, -0.1320, -1.3402, -1.4471]])
# 2
# step : 40
# [[13  0  0]
#  [ 1 10  2]
#  [ 0  2 10]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        13
#            1       0.83      0.77      0.80        13
#            2       0.83      0.83      0.83        12
#
#     accuracy                           0.87        38
#    macro avg       0.87      0.87      0.87        38
# weighted avg       0.87      0.87      0.87        38
#
# 正解率 : 0.868421052631579
# 1
# tensor([[-1.1430,  0.0982, -1.2834, -1.3154]])
# 2
# 1
# tensor([[-1.0218,  0.7888, -1.2834, -1.3154]])
# 2
# 1
# tensor([[2.4920, 1.7096, 1.5016, 1.0539]])
# 2
# 1
# tensor([[ 1.1592, -0.1320,  0.9901,  1.1856]])
# 2
# 1
# tensor([[-1.1430, -1.2830,  0.4217,  0.6590]])
# 2
# 1
# tensor([[ 0.3110, -1.0528,  1.0469,  0.2641]])
# 2
# 1
# tensor([[ 2.2497, -1.0528,  1.7858,  1.4488]])
# 2
# 1
# tensor([[-0.2948, -1.2830,  0.0807, -0.1308]])
# 2
# 1
# tensor([[-4.1601e-01, -1.0528e+00,  3.6490e-01,  8.7755e-04]])
# 2
# 1
# tensor([[-0.1737,  1.7096, -1.1697, -1.1838]])
# 2
# step : 50
# [[13  0  0]
#  [ 1  8  4]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        13
#            1       1.00      0.62      0.76        13
#            2       0.75      1.00      0.86        12
#
#     accuracy                           0.87        38
#    macro avg       0.89      0.87      0.86        38
# weighted avg       0.90      0.87      0.86        38
#
# 正解率 : 0.868421052631579
# 1
# tensor([[-0.0525, -0.8226,  0.7628,  0.9223]])
# 2
# 1
# tensor([[-0.7795,  2.4002, -1.2834, -1.4471]])
# 2
# 1
# tensor([[-0.9007,  1.0190, -1.3402, -1.1838]])
# 2
# 1
# tensor([[1.0380, 0.5586, 1.1038, 1.7121]])
# 2
# 1
# tensor([[ 0.3110, -0.1320,  0.6491,  0.7907]])
# 2
# 1
# tensor([[ 0.9168, -0.1320,  0.3649,  0.2641]])
# 2
# 1
# tensor([[-1.5065,  0.7888, -1.3402, -1.1838]])
# 2
# 1
# tensor([[-0.4160, -1.5132, -0.0330, -0.2624]])
# 2
# 1
# tensor([[ 1.1592, -0.5924,  0.5922,  0.2641]])
# 2
# 1
# tensor([[-0.9007, -1.2830, -0.4308, -0.1308]])
# 2
# step : 60
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  3  9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.80      0.92      0.86        13
#            2       0.90      0.75      0.82        12
#
#     accuracy                           0.89        38
#    macro avg       0.90      0.89      0.89        38
# weighted avg       0.90      0.89      0.89        38
#
# 正解率 : 0.8947368421052632
# 1
# tensor([[-0.1737, -1.2830,  0.7059,  1.0539]])
# 2
# 1
# tensor([[-0.5372,  1.9398, -1.1697, -1.0522]])
# 2
# 1
# tensor([[-0.4160, -1.7434,  0.1375,  0.1325]])
# 2
# 1
# tensor([[ 2.2497, -0.5924,  1.6722,  1.0539]])
# 2
# 1
# tensor([[-0.2948, -0.1320,  0.4217,  0.3958]])
# 2
# 1
# tensor([[1.4015, 0.3284, 0.5354, 0.2641]])
# 2
# 1
# tensor([[-1.7489, -0.3622, -1.3402, -1.3154]])
# 2
# 1
# tensor([[-0.1737,  3.0908, -1.2834, -1.0522]])
# 2
# 1
# tensor([[-0.6583,  1.4794, -1.2834, -1.3154]])
# 2
# 1
# tensor([[-1.0218,  1.0190, -1.2266, -0.7889]])
# 2
# step : 70
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  2 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.86      0.92      0.89        13
#            2       0.91      0.83      0.87        12
#
#     accuracy                           0.92        38
#    macro avg       0.92      0.92      0.92        38
# weighted avg       0.92      0.92      0.92        38
#
# 正解率 : 0.9210526315789473
# 1
# tensor([[ 0.1898, -0.1320,  0.5922,  0.7907]])
# 2
# 1
# tensor([[-1.1430,  0.0982, -1.2834, -1.4471]])
# 2
# 1
# tensor([[ 1.0380, -0.1320,  0.7059,  0.6590]])
# 2
# 1
# tensor([[-0.1737, -1.0528, -0.1466, -0.2624]])
# 2
# 1
# tensor([[-1.3854,  0.3284, -1.3971, -1.3154]])
# 2
# 1
# tensor([[-1.5065,  1.2492, -1.5676, -1.3154]])
# 2
# 1
# tensor([[1.2803, 0.3284, 1.1038, 1.4488]])
# 2
# 1
# tensor([[ 0.6745, -0.5924,  1.0469,  1.3172]])
# 2
# 1
# tensor([[-1.0218,  0.3284, -1.4539, -1.3154]])
# 2
# 1
# tensor([[-0.0525, -0.8226,  0.1944, -0.2624]])
# 2
# step : 80
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  2 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.86      0.92      0.89        13
#            2       0.91      0.83      0.87        12
#
#     accuracy                           0.92        38
#    macro avg       0.92      0.92      0.92        38
# weighted avg       0.92      0.92      0.92        38
#
# 正解率 : 0.9210526315789473
# 1
# tensor([[-1.5065,  0.0982, -1.2834, -1.3154]])
# 2
# 1
# tensor([[ 0.5533, -1.2830,  0.6491,  0.3958]])
# 2
# 1
# tensor([[-1.7489, -0.1320, -1.3971, -1.3154]])
# 2
# 1
# tensor([[ 0.5533, -0.3622,  1.0469,  0.7907]])
# 2
# 1
# tensor([[-0.5372, -0.1320,  0.4217,  0.3958]])
# 2
# 1
# tensor([[ 0.0687, -0.1320,  0.2512,  0.3958]])
# 2
# 1
# tensor([[ 0.6745, -0.8226,  0.8764,  0.9223]])
# 2
# 1
# tensor([[ 0.7957, -0.5924,  0.4786,  0.3958]])
# 2
# 1
# tensor([[0.5533, 0.5586, 0.5354, 0.5274]])
# 2
# 1
# tensor([[ 0.1898, -0.8226,  0.7628,  0.5274]])
# 2
# step : 90
# [[13  0  0]
#  [ 0 13  0]
#  [ 0  7  5]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.65      1.00      0.79        13
#            2       1.00      0.42      0.59        12
#
#     accuracy                           0.82        38
#    macro avg       0.88      0.81      0.79        38
# weighted avg       0.88      0.82      0.80        38
#
# 正解率 : 0.8157894736842105
# 1
# tensor([[-0.2948, -0.1320,  0.1944,  0.1325]])
# 2
# 1
# tensor([[ 0.5533, -0.5924,  0.7628,  0.3958]])
# 2
# 1
# tensor([[-1.0218,  1.2492, -1.3402, -1.3154]])
# 2
# 1
# tensor([[ 0.4322, -0.5924,  0.5922,  0.7907]])
# 2
# 1
# tensor([[-1.0218,  1.0190, -1.3971, -1.1838]])
# 2
# 1
# tensor([[0.5533, 0.5586, 1.2743, 1.7121]])
# 2
# 1
# tensor([[1.2803, 0.0982, 0.9333, 1.1856]])
# 2
# 1
# tensor([[0.5533, 0.7888, 1.0469, 1.5805]])
# 2
# 1
# tensor([[ 0.1898, -0.3622,  0.4217,  0.3958]])
# 2
# 1
# tensor([[-0.9007,  1.7096, -1.0560, -1.0522]])
# 2
# step : 100
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.92      0.96        13
#            2       0.92      1.00      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
# 正解率 : 0.9736842105263158
# 1
# tensor([[1.1592, 0.3284, 1.2175, 1.4488]])
# 2
# 1
# tensor([[-0.1737, -0.3622,  0.2512,  0.1325]])
# 2
# 1
# tensor([[-0.9007,  1.0190, -1.3402, -1.3154]])
# 2
# 1
# tensor([[-0.4160,  1.0190, -1.3971, -1.3154]])
# 2
# 1
# tensor([[-0.0525, -0.8226,  0.0807,  0.0009]])
# 2
# 1
# tensor([[1.0380, 0.0982, 0.3649, 0.2641]])
# 2
# 1
# tensor([[-0.4160,  2.6304, -1.3402, -1.3154]])
# 2
# 1
# tensor([[-0.4160, -1.2830,  0.1375,  0.1325]])
# 2
# 1
# tensor([[0.4322, 0.7888, 0.9333, 1.4488]])
# 2
# 1
# tensor([[1.2803, 0.0982, 0.6491, 0.3958]])
# 2
# step : 110
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.92      0.96        13
#            2       0.92      1.00      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
# 正解率 : 0.9736842105263158
# 1
# tensor([[ 0.7957, -0.1320,  1.1606,  1.3172]])
# 2
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.set_title("MSE ")

ax1.plot(loss_stack)
ax1.set_xlabel("step")
plt.show()

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.set_title("MSE ")

ax1.plot(test_loss_stack)
ax1.set_xlabel("step")
plt.show()
