# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from ML2_lib import DC_SGD
from ML2_lib import RV_SGDAve
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris
from sklearn import model_selection
from ML2_lib import models
from ML2_lib import SGDByTorch

# %%
real_data = load_iris()
x = real_data.data

scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)
# x = x.T

# %%
y = real_data.target
y = y.T

data_train, data_test, label_train, label_test = model_selection.train_test_split(x, y)
w_dim = data_train.shape[1]
class_num = 3
unit_num = 3
model = models.FF_L1(w_num=w_dim, c_num=class_num,unit_num=unit_num)
# model = models.LinearClassification(4,3)
hoge = SGDByTorch.SGDTorchCheck(lr=1)

# %%
sgd_model, loss_stack, test_loss_stack, accuracy_stack = hoge.learn(x=data_train, y=label_train,
                                                                                      model=model, class_num=class_num,
                                                                                      X_test=data_test,
                                                                                      Y_test=label_test)
# Out:
# step : 0
# OrderedDict([('fc1.weight', tensor([[ 2.8607,  1.2618, -3.0666,  3.8217],
#         [-0.6327,  0.1333, -3.8901,  1.9271],
#         [-0.1767,  3.7902,  1.5006, -3.0657]])), ('fc1.bias', tensor([0., 0., 0.])), ('fc2.weight', tensor([[-2.6165,  1.0146, -1.8301],
#         [ 1.6343, -1.8651, -1.7835],
#         [ 2.4360,  3.5858,  1.7383]])), ('fc2.bias', tensor([0., 0., 0.]))])
# [[ 0  0 12]
#  [ 8  0  6]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        12
#            1       0.00      0.00      0.00        14
#            2       0.40      1.00      0.57        12
#
#     accuracy                           0.32        38
#    macro avg       0.13      0.33      0.19        38
# weighted avg       0.13      0.32      0.18        38
#
# 正解率 : 0.3157894736842105
# test loss : 8.626662254333496
# ...

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.set_title("MSE ")

ax1.plot(loss_stack)
ax1.set_xlabel("step")
plt.show()

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.set_title("MSE ")

ax1.plot(test_loss_stack)
ax1.set_xlabel("step")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c18668046546> in <module>
# ----> 1 swa_stack
#       2
#
# NameError: name 'swa_stack' is not defined
