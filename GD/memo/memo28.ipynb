# %%
import numpy as np
import pandas as pd

from ML2_lib import many_trials_SGD, many_trials_SGDAve
from ML2_lib import models
from ML2_lib import plot_set
import matplotlib.pyplot as plt

# %%
result_test_loss,result_accuracy, col_name_list = many_trials_SGD.ManyTrialsSGDMNIST().k_ex(trial_num=3,model_type="linear",lr=0.3,k_list=[1,2,4,5,8,10])
# Out:
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/torchvision/datasets/mnist.py:62: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/torchvision/datasets/mnist.py:67: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/torchvision/datasets/mnist.py:52: UserWarning: train_labels has been renamed targets
#   warnings.warn("train_labels has been renamed targets")
# /Users/naoki/.pyenv/versions/ML2/lib/python3.8/site-packages/torchvision/datasets/mnist.py:57: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# ...

# %%
result_accuracy
# Out:
# [[0.8699, 0.8736, 0.8731], [0.8195, 0.8311, 0.8428], [0.8454, 0.8135, 0.8324]]

# %%
result_test_loss
# Out:
# [[3.0696868896484375, 3.1937546730041504, 3.270031690597534],
#  [4.558282852172852, 3.8717706203460693, 3.574782133102417],
#  [3.3569679260253906, 4.4158806800842285, 3.4611175060272217]]

# %%
fdic = {
    "size": 20,
}

columns = col_name_list
fig = plt.figure(figsize=(40.0, 8.0))
ax1 = fig.add_subplot(111)


ax1.boxplot(result_accuracy)
ax1.set_xticklabels(columns, fontsize=15)
ax1.set_title('SGD 25 trials accuracy dataset adult', fontsize=15)
ax1.set_xlabel('learning late - late', fontdict=fdic)
ax1.set_ylabel('accuracy')

plt.savefig("SGD_25_adult_accuracy.png")

plt.show()
