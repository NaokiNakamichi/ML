# %%
import numpy as np
import pandas as pd

from ML2_lib import many_trials_SGD, many_trials_SGDAve
from ML2_lib import models

# %%
name_path = "data/adult/adult_classification.names"
train_path = "data/adult/adult_classification.csv"
test_path = "data/adult/adult_classification.test"
w_dim = 104
class_num = 2
unit_num = 4
model_1 = models.LinearClassification(w_num=w_dim, c_num=class_num)
model_2 = models.FF_L1(w_num=w_dim, c_num=class_num, unit_num=unit_num)
model_3 = models.FF_L2(w_num=w_dim, c_num=class_num, unit_num=unit_num)
model_list = [model_1, model_2, model_3]
model_name_list = ["Linear", "FF_L1", "FF_L2"]
lr_list = [0.0001, 0.001, 0.01, 0.1]
many_learner = many_trials_SGD.ExManyTrials(train_path=train_path, name_path=name_path, test_path=test_path)

# %%
result_accuracy, result_test_loss, col_name_list = many_learner.ex_many_settings(trial_num=25,
                                                                                 model_name_list=model_name_list,
                                                                                 lr_list=lr_list, model_list=model_list)
# Out:
# ...
# 100%|██████████| 25/25 [04:42<00:00, 11.28s/it]
# ['lr_0.0001_model_Linear', 'lr_0.0001_model_FF_L1', 'lr_0.0001_model_FF_L2', 'lr_0.001_model_Linear', 'lr_0.001_model_FF_L1', 'lr_0.001_model_FF_L2', 'lr_0.01_model_Linear', 'lr_0.01_model_FF_L1', 'lr_0.01_model_FF_L2', 'lr_0.1_model_Linear', 'lr_0.1_model_FF_L1', 'lr_0.1_model_FF_L2']

# %%
hoge =pd.DataFrame(np.array(result_accuracy).T, columns=col_name_list)

# %%
many_learner = many_trials_SGDAve.ExManyTrials(train_path=train_path, name_path=name_path, test_path=test_path)

# %%
result_accuracy, _, col_name_list = many_learner.ex_many_settings(trial_num=25, model_name_list=model_name_list,
                                                                  lr_list=lr_list, model_list=model_list)
# Out:
# ...
# 100%|██████████| 25/25 [04:18<00:00, 10.33s/it]
#
# ...
# 100%|██████████| 25/25 [06:01<00:00, 14.47s/it]
#
# ...
# 100%|██████████| 25/25 [04:17<00:00, 10.31s/it]
#
# ...
# 100%|██████████| 25/25 [06:00<00:00, 14.42s/it]
#
# ...
# 100%|██████████| 25/25 [04:09<00:00,  9.99s/it]
#
# ...
# 100%|██████████| 25/25 [05:49<00:00, 13.98s/it]
#
# ...
# 100%|██████████| 25/25 [04:09<00:00,  9.99s/it]
#
# ...
# 100%|██████████| 25/25 [05:50<00:00, 14.03s/it]
#
# ...
# 100%|██████████| 4/4 [1:10:29<00:00, 1057.38s/it]
# ['lr_0.0001_model_Linear', 'lr_0.0001_model_FF_L1', 'lr_0.0001_model_FF_L2', 'lr_0.001_model_Linear', 'lr_0.001_model_FF_L1', 'lr_0.001_model_FF_L2', 'lr_0.01_model_Linear', 'lr_0.01_model_FF_L1', 'lr_0.01_model_FF_L2', 'lr_0.1_model_Linear', 'lr_0.1_model_FF_L1', 'lr_0.1_model_FF_L2']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-7dfeb5e2ae97> in <module>
# ...

# %%
# Out:
#     lr_0.0001_model_Linear  lr_0.0001_model_FF_L1  lr_0.0001_model_FF_L2  \
# 0                 0.675365               0.749336               0.746082
# 1                 0.517530               0.658566               0.754316
# 2                 0.686521               0.641036               0.748672
# 3                 0.523174               0.703785               0.754250
# 4                 0.487716               0.712218               0.542696
# 5                 0.567065               0.666999               0.752125
# 6                 0.681541               0.703187               0.747477
# 7                 0.600199               0.701992               0.711952
# 8                 0.709827               0.648805               0.386388
# 9                 0.550332               0.688446               0.753718
# 10                0.634794               0.754316               0.752988
# 11                0.551062               0.739309               0.720651
# ...

# %%
pd.DataFrame(np.array(result_accuracy).T, columns=col_name_list)

# %%
hoge.to_csv("hoge_12161507.csv",index=False)

# %%
pd.read_csv("hoge_12161507.csv")
# Out:
#     lr_0.0001_model_Linear  lr_0.0001_model_FF_L1  lr_0.0001_model_FF_L2  \
# 0                 0.675365               0.749336               0.746082
# 1                 0.517530               0.658566               0.754316
# 2                 0.686521               0.641036               0.748672
# 3                 0.523174               0.703785               0.754250
# 4                 0.487716               0.712218               0.542696
# 5                 0.567065               0.666999               0.752125
# 6                 0.681541               0.703187               0.747477
# 7                 0.600199               0.701992               0.711952
# 8                 0.709827               0.648805               0.386388
# 9                 0.550332               0.688446               0.753718
# 10                0.634794               0.754316               0.752988
# 11                0.551062               0.739309               0.720651
# ...
