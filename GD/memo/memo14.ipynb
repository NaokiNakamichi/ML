# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.001
noise = "lognormal"
c = 1
w_init = np.array([2, 2])
E_var = 1.75
n = 10000
k_list = [1, 2, 4, 5, 10]
son = loss.RosenBrock(d=d, noise_type=noise, E_var=1.75,f_E_var=1.75,noise_type_f=noise)

# %%
w_init = np.array([0, 0])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [-3.982606910784258]
# tmp_loss [array([-3.98260691])]
# 0
# valid_loss_store [-0.22984900818935805, 1.437948772856995]
# tmp_loss [array([-1.26961634]), array([4.14551388])]
# 0
# valid_loss_store [-3.5600875183935643, -3.9599127848076296, -1.1149720240662129, -3.657560326089388]
# tmp_loss [array([-3.80989447]), array([-4.20655066]), array([-3.50522619]), array([-0.86554169])]
# 1
# valid_loss_store [-3.1464602813183538, -3.531214140147616, -2.098594805407808, -3.047153524523429, -2.4223644571872756]
# tmp_loss [array([-4.27283855]), array([-2.42236446]), array([-4.24359522]), array([6.30553701]), array([3.823323])]
# 1
# valid_loss_store [-3.4404149628460905, -3.0898052049553106, -2.157693939447984, -3.0329041148656337, -3.6661927845592817, -2.65645712757508, -2.790353598085151, -3.1428192759147264, -2.915832471682541, -2.7772850012098576]
# tmp_loss [array([-1.96526785]), array([-2.57457226]), array([-2.9370993]), array([-3.62453874]), array([-3.57745835]), array([-3.18583765]), array([-3.52784326]), array([-2.6174707]), array([0.52283323]), array([-0.1828374])]
# 4
