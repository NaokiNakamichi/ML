# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import lines
import matplotlib.cm as cm
import tqdm
from tqdm.notebook import tqdm as tqdm

import model_opt
import data_generate
import algo_GD

# %%
f = model_opt.RosenBrock()

x = np.arange(-0.5, 1.5, 0.1)
y = np.arange(-0.5, 1.5, 0.1)
X, Y = np.meshgrid(x, y)
Z = f.f_opt([X,Y])

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(Y,X , Z)
plt.show()

# %%
x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)
X, Y = np.meshgrid(x, y)

sh = np.array([X,Y]).shape
noise = np.re
Z = f.g_opt([X,Y])[0]

print(Z.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-46afbc743408> in <module>
#       5 np.array([X,Y]).shape
#       6
# ----> 7 Z = f.g_opt([X,Y])[0]
#       8
#       9 print(Z.shape)
#
# ~/ML/GD/model_opt.py in g_opt(self, w)
#     382                 tmp[i] = 100 * (-4) * w[i] * (w[i + 1] - w[i] ** 2) + 2 * (w[i] - 1) + 100 * 2 * (w[i] - w[i - 1] ** 2)
#     383
# --> 384         tmp = tmp + self.noise_value
#     385
#     386         return tmp
#
# ValueError: operands could not be broadcast together with shapes (2,40,40) (2,)

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("f(x, y)")

ax.plot_surface(X, Y, Z)
plt.show()

# %%
Z = f.g_opt([0,0])
Z
# Out:
# array([-2.,  0.])

# %%
Z = f.f_opt([0,0])
Z
# Out:
# 1.0

# %%
xvals = np.arange(-4,4, 0.1)
yvals = np.arange(-4,4, 0.1)
X, Y = np.meshgrid(xvals, yvals)
Z = f.g_opt([X,Y])[0]

plt.pcolor(X, Y, Z,cmap=plt.cm.rainbow)
plt.colorbar()

# %%
xvals = np.arange(-4,4, 0.1)
yvals = np.arange(-4,4, 0.1)
X, Y = np.meshgrid(xvals, yvals)
Z = f.g_opt([X,Y])[1]

plt.pcolor(X, Y, Z,cmap=plt.cm.rainbow)
plt.colorbar()

# %%
np.min(Z)
# Out:
# 1.9918737856830548e-29

# %%
xvals
# Out:
# array([-4.00000000e+00, -3.90000000e+00, -3.80000000e+00, -3.70000000e+00,
#        -3.60000000e+00, -3.50000000e+00, -3.40000000e+00, -3.30000000e+00,
#        -3.20000000e+00, -3.10000000e+00, -3.00000000e+00, -2.90000000e+00,
#        -2.80000000e+00, -2.70000000e+00, -2.60000000e+00, -2.50000000e+00,
#        -2.40000000e+00, -2.30000000e+00, -2.20000000e+00, -2.10000000e+00,
#        -2.00000000e+00, -1.90000000e+00, -1.80000000e+00, -1.70000000e+00,
#        -1.60000000e+00, -1.50000000e+00, -1.40000000e+00, -1.30000000e+00,
#        -1.20000000e+00, -1.10000000e+00, -1.00000000e+00, -9.00000000e-01,
#        -8.00000000e-01, -7.00000000e-01, -6.00000000e-01, -5.00000000e-01,
#        -4.00000000e-01, -3.00000000e-01, -2.00000000e-01, -1.00000000e-01,
#         3.55271368e-15,  1.00000000e-01,  2.00000000e-01,  3.00000000e-01,
#         4.00000000e-01,  5.00000000e-01,  6.00000000e-01,  7.00000000e-01,
# ...

# %%
np.unravel_index(np.argmin(Z), Z.shape)
# Out:
# (15, 15)

# %%
X[15][15]
# Out:
# 0.9999999999999996

# %%
Y[15][15]
# Out:
# 0.9999999999999996

# %%
xvals = np.arange(-1,1.1, 0.1)
yvals = np.arange(-1,1.1, 0.1)
X, Y = np.meshgrid(xvals, yvals)
Z = f.f_opt([X,Y])

plt.pcolor(X, Y, Z,cmap=plt.cm.rainbow)
plt.colorbar()

# %%
f.f_opt([0,-1])
# Out:
# 101.0
