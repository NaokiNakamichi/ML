# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.1
noise = "lognormal"
c = 1
E_var = 1.75
n = 10000
k_list = [1, 2, 4, 5, 10, 20]
son = loss.Rastrigin(d=d, noise_type=None, E_var=E_var)

# %%
son.f_opt(w=[10,10])
# Out:
# 200.0

# %%
w_star = son.w_star
grid_x_max, grid_y_max = 10,10
grid_x_min, grid_y_min = -10,-10
xvals = np.arange(grid_x_min, grid_x_max, 0.1)
yvals = np.arange(grid_y_min, grid_y_max, 0.1)
X, Y = np.meshgrid(xvals, yvals)
Z = son.f_opt([X, Y])

# %%
fig, axes = plt.subplots(1, 1, figsize=(6, 6))
axes.pcolor(X, Y, Z, cmap=plt.cm.rainbow, shading='auto')

# %%
Z = son.g_opt([X, Y])[0]

# %%
Z
