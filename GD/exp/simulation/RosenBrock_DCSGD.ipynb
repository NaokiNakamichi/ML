# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

from ML2_lib import DC_SGD
from ML2_lib import loss
from ML2_lib import plot_set

# %%
d = 2
n= 10000
lr = 0.001
noise = "lognormal"
c = 2
son = loss.RosenBrock(d=d,noise_type=noise,E_var=1.25)
DC = DC_SGD.DCSGDByW(model_opt=son,c=1,n=n,lr=lr)

# %%
k = 5

rng = np.random.default_rng()
# w_init = rng.uniform(-c,c,size=d)
w_init = np.array([2,2])
tr,ftr = DC.transition(k,w_init)

plot_set.w_value_2d_heatmap(f=son,w_store=np.array(tr),_t_max=len(tr))
# Out:
# (2000, 5, 2)

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.plot(ftr)
ax1.set_xlabel("step")

plt.show()

# %%
k = 1
tr,ftr = DC.transition(k,w_init)
plot_set.w_value_2d_heatmap(f=son,w_store=np.array(tr),_t_max=len(tr))
# Out:
# (10000, 1, 2)

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.plot(ftr)
ax1.set_xlabel("step")

plt.show()

# %%
_, result = DC.many_trails(trial_num=100,max_k=5,w_init=w_init)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1e3feb5a4a6d> in <module>
# ----> 1 _, result = DC.many_trails(trial_num=100,max_k=5,w_init=w_init)
#
# ~/ML2/GD/ML2_lib/DC_SGD.py in many_trails(self, trial_num, max_k, w_init)
#     390         result_loss = []  # 過剰期待損失の最終結果　トライアル数*分割数k
#     391         for _ in tqdm(range(trial_num)):
# --> 392             w_trial, loss_store = self.trial_k(max_k=max_k,w_init=w_init)
#     393             result_w.append(np.array(w_trial))
#     394             result_loss.append(np.array(loss_store))
#
# ~/ML2/GD/ML2_lib/DC_SGD.py in trial_k(self, max_k, w_init)
#     378
#     379         for k in range(1, max_k + 1):
# --> 380             w, _ = self.learn(k=k, w_init=w_init)
#     381             w_trial.append(w)
#     382
#
# ~/ML2/GD/ML2_lib/DC_SGD.py in learn(self, k, w_init)
#     337             core = algo_sgd.SGD(w_init=w_init, a=self.lr, t_max=core_num - 1, fixed_lr=self.fixed_lr)
#     338             for _ in core:
# --> 339                 core.update(self.model_opt)
#     340             core_store.append(core.wstore)
#     341             model_store.append(core.w)
#
# ~/ML2/GD/ML2_lib/algo_sgd.py in update(self, model)
#      43                     self.w = self.w - self.a * grad
#      44         else:
# ---> 45             grad = model.g_opt(w=self.w)
#      46             if self.fixed_lr:
#      47                 self.w = self.w - self.a * grad
#
# ~/ML2/GD/ML2_lib/loss.py in g_opt(self, w)
#      70
#      71         if self.noise_type:
# ---> 72             tmp = tmp + self.generate_noise()
#      73
#      74         return tmp
#
# KeyboardInterrupt:

# %%
result.shape

# %%
k_list = [0,1,3,4]
k_string = ["1","2","4","5"]
title = "hoge"
plot_set.box_plot_k(result, k_list, k_string, title)

# %%
result
