# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

from ML2_lib import DC_SGD
from ML2_lib import loss
from ML2_lib import plot_set

# %%
d = 2
n= 10000
lr = 0.001
noise = "lognormal"
c = 2
son = loss.RosenBrock(d=d,noise_type=noise,E_var=1.75)
DC = DC_SGD.DCSGDByW(model_opt=son,c=1,n=n,lr=lr)

# %%
k = 5

rng = np.random.default_rng()
# w_init = rng.uniform(-c,c,size=d)
w_init = np.array([2,2])
tr,ftr = DC.transition(k,w_init)

plot_set.w_value_2d_heatmap(f=son,w_store=np.array(tr),_t_max=len(tr))
# Out:
# (2000, 5, 2)

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.plot(ftr)
ax1.set_xlabel("step")

plt.show()

# %%
k = 1
tr,ftr = DC.transition(k,w_init)
plot_set.w_value_2d_heatmap(f=son,w_store=np.array(tr),_t_max=len(tr))
# Out:
# (10000, 1, 2)

# %%
_, result = DC.many_trails(trial_num=10,max_k=5,w_init=w_init)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# /Users/naoki/ML2/GD/ML2_lib/loss.py:65: RuntimeWarning: overflow encountered in double_scalars
#   tmp[i] = 100 * (-4) * w[i] * (w[i + 1] - w[i] ** 2) + 2 * (w[i] - 1)
# /Users/naoki/ML2/GD/ML2_lib/algo_sgd.py:47: RuntimeWarning: invalid value encountered in subtract
#   self.w = self.w - self.a * grad

# %%
result.shape
# Out:
# (10, 5)

# %%
fig = plt.figure(figsize=(10.0, 8.0))
ax1 = fig.add_subplot(111)

ax1.plot(ftr)
ax1.set_xlabel("step")

plt.show()

# %%
k_list = [0,1,3]
k_string = ["1","2","4"]
title = "hoge"
plot_set.box_plot_k(result, k_list, k_string, title)

# %%
result
# Out:
# array([[1.49908324e+00, 8.42163051e-02, 3.95299956e-01, 2.43356041e+00,
#         1.40208881e+02],
#        [2.10369149e-02, 3.31301979e-01, 9.19387041e-03, 4.17397518e+00,
#         2.21024657e-02],
#        [2.81754888e-02, 1.53251327e+01, 1.65328133e-01, 2.44136924e+00,
#         2.74730323e+02],
#        [4.08844085e-02, 9.40470438e+00, 6.07304698e+00, 1.90909583e-01,
#         1.67213528e+01],
#        [1.42653563e-01, 6.74949183e-01, 3.92050046e-01, 4.59251460e+00,
#         3.14822369e+00],
#        [4.61254462e-02, 8.38091068e-01, 4.64852768e-01, 4.03105050e-01,
#         2.38427084e+02],
#        [2.04079932e-01, 1.44119797e+00, 1.87641943e+00, 2.65495043e+00,
#         1.25236701e+01],
#        [6.83027571e-02, 4.01138118e+01,            nan, 6.82679098e-01,
#         8.78413523e-01],
#        [1.19493369e-01, 1.26283189e-01, 2.24848642e-01, 8.88498184e-02,
#         1.32715908e+00],
#        [6.36431633e-02, 6.83170296e-01, 8.54118642e-02, 7.66932512e-01,
#         3.74859407e-02]])
