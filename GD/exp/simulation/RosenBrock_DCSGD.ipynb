# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

from ML2_lib import DCSGD_exp
from ML2_lib import loss
from ML2_lib import plot_set

# %%
d = 2
trial_num = 100
lr = 0.001
noise = "lognormal"
c = 1
son = loss.RosenBrock(d=d,noise_type=noise,E_var=1.75)
w_init = np.array([2,2])
E_var = 1.75
n = 10000
k_list = [0,1,3,4,9]

# %%
n_list = [100,1000,10000.100000]
DCSGD_exp.n_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init=w_init,k_list=k_list,n_list=n_list)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
E_var_list = [1.2,1.75,1.9]
DCSGD_exp.e_var_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var_list=E_var_list,w_init=w_init,k_list=k_list,n=n)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
d_list = [8,64,128,256,512]
DCSGD_exp.d_exp(d_list=d_list,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init=w_init,k_list=k_list,n=n)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
