# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.1
noise = "normal"
c = 1
w_init = np.array([2, 2])
E_var = 1.75
n = 10000
k_list = [1, 2, 4, 5, 10]
son = loss.Ackley(d=d, noise_type=noise, E_var=1.75)

# %%
w_init = np.array([5, 5])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [16.78985275792818]
# tmp_loss [array([16.78985276])]
# 0
# valid_loss_store [17.748637751537757, 15.971638291339323]
# tmp_loss [array([15.97163829]), array([15.97163829])]
# 1
# valid_loss_store [15.940797693882724, 16.924071020437122, 16.088784471388635, 17.165157663320805]
# tmp_loss [array([17.16515766]), array([17.16515766]), array([17.16515766]), array([17.16515766])]
# 0
# valid_loss_store [15.593683180610808, 15.265018507256215, 17.570512292708052, 14.805780182135997, 14.93713989602405]
# tmp_loss [array([14.9371399]), array([14.9371399]), array([14.9371399]), array([14.9371399]), array([14.9371399])]
# 3
# valid_loss_store [15.136542968274311, 13.774156750361852, 14.56217010719264, 13.828103813250333, 15.597198837068182, 15.021667120403034, 15.65102338134827, 15.595009888255198, 13.459878605794268, 14.241542332908672]
# tmp_loss [array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233]), array([14.24154233])]
# 8

# %%
k_w_rv
# Out:
# [array([-28.71495277, -24.28311744]),
#  array([-4.51808196, -4.67057374]),
#  array([ 0.43553193, -0.74377577]),
#  array([-0.43357545,  0.58253798]),
#  array([-1.22405961,  2.99735031])]

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 10])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [14.912337655373543]
# tmp_loss [array([14.91233766])]
# 0
# valid_loss_store [14.929450358947985, 14.784247272319456]
# tmp_loss [array([14.78424727]), array([14.78424727])]
# 1
# valid_loss_store [15.803297183072583, 16.022106617980917, 16.201137928638822, 14.653793557807571]
# tmp_loss [array([14.65379356]), array([14.65379356]), array([14.65379356]), array([14.65379356])]
# 3
# valid_loss_store [15.996881055620765, 16.28766847236389, 15.464438902408057, 16.513036313226866, 16.393467468302564]
# tmp_loss [array([16.39346747]), array([16.39346747]), array([16.39346747]), array([16.39346747]), array([16.39346747])]
# 2
# valid_loss_store [17.580612140756195, 17.42273134315202, 17.338417047031626, 17.23500401984487, 17.21466942990738, 17.075472831890266, 17.387667683062272, 17.137357293215054, 16.203888391606156, 16.81860818136225]
# tmp_loss [array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818]), array([16.81860818])]
# 8

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 30])
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [19.694503895929554]
# tmp_loss [array([19.6945039])]
# 0
# valid_loss_store [19.87401080229126, 19.952602867142005]
# tmp_loss [array([19.95260287]), array([19.95260287])]
# 0
# valid_loss_store [20.37461554292151, 20.3273263241908, 20.31332327627536, 20.40901219413302]
# tmp_loss [array([20.40901219]), array([20.40901219]), array([20.40901219]), array([20.40901219])]
# 2
# valid_loss_store [20.253730729373384, 20.339295417134316, 20.45424370748024, 20.43370006484159, 20.555624890186078]
# tmp_loss [array([20.55562489]), array([20.55562489]), array([20.55562489]), array([20.55562489]), array([20.55562489])]
# 0
# valid_loss_store [21.17783494029803, 21.48377763384011, 21.27678572909944, 21.392069518042245, 21.21679158888924, 21.38394033543986, 21.452310409942243, 21.406846665111654, 21.20753527113213, 21.67949687357599]
# tmp_loss [array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687]), array([21.67949687])]
# 0

# %%
noise = "normal"
son = loss.RosenBrock(d=d, noise_type=noise, E_var=2.2)
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([2, 2])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title="")
# Out:
# valid_loss_store [0.027495131562459633]
# tmp_loss [array([0.02749513])]
# 0
# valid_loss_store [0.04068892579091474, 0.03766130756975643]
# tmp_loss [array([0.03766131]), array([0.03766131])]
# 1
# valid_loss_store [0.05775959323678534, 0.0663050472242008, 0.05748075452881741, 0.06783701915844721]
# tmp_loss [array([0.06783702]), array([0.06783702]), array([0.06783702]), array([0.06783702])]
# 2
# valid_loss_store [0.06469124344865097, 0.057568751527873455, 0.052751469218022394, 0.07583563114004356, 0.060661261184641636]
# tmp_loss [array([0.06066126]), array([0.06066126]), array([0.06066126]), array([0.06066126]), array([0.06066126])]
# 2
# valid_loss_store [0.07479522353926886, 0.07264754520236003, 0.06449160114514407, 0.07256375864765942, 0.06358421974688225, 0.08328533594160234, 0.06590480663801895, 0.07480262764661215, 0.07050044468308528, 0.06750223996432411]
# tmp_loss [array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224]), array([0.06750224])]
# 4

# %%
# 対数正規分布　ノイズ強
noise = "lognormal"
son = loss.RosenBrock(d=d, noise_type=noise, E_var=1.9)
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([2, 2])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title="")
# Out:
# valid_loss_store [0.5626034186006079]
# tmp_loss [array([0.56260342])]
# 0
# valid_loss_store [0.5828649220376865, 0.15661082272370758]
# tmp_loss [array([0.15661082]), array([0.15661082])]
# 1
# valid_loss_store [6.184208390741469, 0.10133181025215285, 0.09963528141479643, 0.019194396717874623]
# tmp_loss [array([0.0191944]), array([0.0191944]), array([0.0191944]), array([0.0191944])]
# 3
# valid_loss_store [0.11586673183209395, 0.46028249486526057, 0.1371513232222195, 0.21139967908985596, 0.1344390545288192]
# tmp_loss [array([0.13443905]), array([0.13443905]), array([0.13443905]), array([0.13443905]), array([0.13443905])]
# 0
# valid_loss_store [0.14682809186072796, 0.07491376118616529, 4.413255781753678, 0.07337333714060673, 0.12155641362044883, 0.08469743798166025, 0.04673067371144162, 0.13947725376571127, 0.16909166753135058, 0.059031199667451045]
# tmp_loss [array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312]), array([0.0590312])]
# 6

# %%
w_init = np.array([0, 5])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# /Users/naoki/ML/GD/ML2_lib/algo_sgd.py:46: RuntimeWarning: overflow encountered in square
#   if 100000000 < np.sum(grad ** 2):
# /Users/naoki/ML/GD/ML2_lib/loss.py:70: RuntimeWarning: overflow encountered in double_scalars
#   tmp[i] = 100 * (-4) * w[i] * (w[i + 1] - w[i] ** 2) + 2 * (w[i] - 1)
# /Users/naoki/ML/GD/ML2_lib/loss.py:72: RuntimeWarning: overflow encountered in double_scalars
#   tmp[i] = 100 * 2 * (w[i] - w[i - 1] ** 2)
# /Users/naoki/ML/GD/ML2_lib/loss.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   tmp[i] = 100 * (-4) * w[i] * (w[i + 1] - w[i] ** 2) + 2 * (w[i] - 1)
# /Users/naoki/ML/GD/ML2_lib/loss.py:72: RuntimeWarning: invalid value encountered in double_scalars
#   tmp[i] = 100 * 2 * (w[i] - w[i - 1] ** 2)
# /Users/naoki/ML/GD/ML2_lib/loss.py:55: RuntimeWarning: overflow encountered in square
#   tmp_1 = 100 * (w[i + 1] - w[i] ** 2) ** 2
# /Users/naoki/ML/GD/ML2_lib/loss.py:56: RuntimeWarning: overflow encountered in square
#   tmp_2 = (w[i] - 1) ** 2
# /Users/naoki/ML/GD/ML2_lib/loss.py:55: RuntimeWarning: overflow encountered in double_scalars
#   tmp_1 = 100 * (w[i + 1] - w[i] ** 2) ** 2
# /Users/naoki/ML/GD/ML2_lib/loss.py:56: RuntimeWarning: overflow encountered in double_scalars
#   tmp_2 = (w[i] - 1) ** 2
# /Users/naoki/ML/GD/ML2_lib/loss.py:55: RuntimeWarning: invalid value encountered in subtract
#   tmp_1 = 100 * (w[i + 1] - w[i] ** 2) ** 2
# /Users/naoki/ML/GD/ML2_lib/loss.py:55: RuntimeWarning: invalid value encountered in double_scalars
#   tmp_1 = 100 * (w[i + 1] - w[i] ** 2) ** 2
# valid_loss_store [nan]
# tmp_loss [array([nan])]
# 0
# valid_loss_store [nan, nan]
# tmp_loss [array([nan]), array([nan])]
# 0
# valid_loss_store [nan, nan, nan, nan]
# tmp_loss [array([nan]), array([nan]), array([nan]), array([nan])]
# 0
# valid_loss_store [nan, nan, nan, nan, nan]
# tmp_loss [array([nan]), array([nan]), array([nan]), array([nan]), array([nan])]
# 0
# /Users/naoki/ML/GD/ML2_lib/algo_sgd.py:49: RuntimeWarning: invalid value encountered in subtract
#   self.w = self.w - self.a * grad
# valid_loss_store [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# tmp_loss [array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan]), array([nan])]
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-65c1ca54cabc> in <module>
#       2 RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
#       3 k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
# ----> 4 plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
#       5                                                   k_selected_index=k_selected_index, f=son)
#       6
#
# ~/ML/GD/ML2_lib/plot_set.py in multiple_w_value_2d_k_candidates_contour(f, k_list, k_list_core_store, _t_max, k_selected_index, title, trajectory)
#     128         grid_x_max, grid_y_max = max(grid_x_max, w_star[0]) + 1, max(grid_y_max, w_star[1]) + 1
#     129         grid_x_min, grid_y_min = min(grid_x_min, w_star[1]) - 1, min(grid_y_min, w_star[1]) - 1
# --> 130         xvals = np.arange(grid_x_min, grid_x_max, ((grid_x_max - grid_x_min) / 500))
#     131         yvals = np.arange(grid_y_min, grid_y_max, ((grid_y_max - grid_y_min) / 500))
#     132         X, Y = np.meshgrid(xvals, yvals)
#
# ValueError: arange: cannot compute length

# %%
k_core_list
