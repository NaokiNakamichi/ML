# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RVSGD_exp

# %%
d = 2
trial_num = 100
lr = 0.001
noise = "lognormal"
c = 1
son = loss.RosenBrock(d=d,noise_type=noise,E_var=1.75)
w_init = np.array([2,2])
E_var = 1.75
n = 10000
k_list = [0,1,3,4,9,19]

# %%
w_init_list = [np.array([0,i]) for i in range(5)]
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
w_init_list = [np.array([0,i]) for i in range(5)]
noise = "normal"
E_var = 2.2
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
w_init_list = [np.array([0,i]) for i in range(5)]
noise = "student_t"
E_var = 5
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
