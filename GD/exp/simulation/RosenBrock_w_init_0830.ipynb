# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RVSGD_exp

# %%
d = 2
trial_num = 100
lr = 0.001

c = 1

n = 10000
k_list = [0,1,3,4,9,19]

# %%
noise = "lognormal"
E_var = 1.75
w_init_list = [np.array([0,i]) for i in range(5)]
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
w_init_list = [np.array([0,i]) for i in range(5)]
noise = "normal"
E_var = 2.2
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/naoki/.pyenv/versions/3.8.6/envs/ML2/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-094af21178c4> in <module>
#       2 noise = "normal"
#       3 E_var = 2.2
# ----> 4 RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
#       5
#
# ~/ML/GD/ML2_lib/RVSGD_exp.py in w_init_exp(d, trial_num, lr, c, noise, E_var, w_init_list, k_list, n)
#      65         son = loss.RosenBrock(d=d, noise_type=noise, E_var=E_var)
#      66         RV = RV_SGDAve.RVSGDByW(model_opt=son, c=c, n=n, lr=lr)
# ---> 67         _, result = RV.many_trails(trial_num=trial_num, max_k=k_list[-1] + 1, w_init=w_init)
#      68         title = f"RVSGD Rosenbrock trial = {trial_num} noise = {noise} D = {d}_sample_num{n} noise var = {E_var}　w_init = {w_init}"
#      69         plot_set.box_plot_k(result, k_list, k_string, title)
#
# ~/ML/GD/ML2_lib/RV_SGDAve.py in many_trails(self, trial_num, max_k, w_init)
#     567         result_loss = []  # 過剰期待損失の最終結果　トライアル数*分割数k
#     568         for _ in tqdm(range(trial_num)):
# --> 569             w_trial, loss_store = self.trial_k(max_k=max_k, w_init=w_init)
#     570             result_w.append(np.array(w_trial))
#     571             result_loss.append(np.array(loss_store))
#
# ~/ML/GD/ML2_lib/RV_SGDAve.py in trial_k(self, max_k, w_init)
#     555
#     556         for k in range(1, max_k + 1):
# --> 557             w, _ = self.learn(k=k, w_init=w_init)
#     558             w_trial.append(w)
#     559
#
# ~/ML/GD/ML2_lib/RV_SGDAve.py in learn(self, k, w_init)
#     438             core = algo_sgd.SGD(w_init=w_init, a=self.lr, t_max=core_num - 1, fixed_lr=self.fixed_lr)
#     439             for _ in core:
# --> 440                 core.update(self.model_opt)
#     441             core_store.append(core.wstore)
#     442             model_store.append(np.mean(core.wstore, axis=0))
#
# ~/ML/GD/ML2_lib/algo_sgd.py in update(self, model)
#      43                     self.w = self.w - self.a * grad
#      44         else:
# ---> 45             grad = model.g_opt(w=self.w)
#      46             if 100000000 < np.sum(grad ** 2):
#      47                 grad *= 0.001
#
# ~/ML/GD/ML2_lib/loss.py in g_opt(self, w)
#      70
#      71         if self.noise_type:
# ---> 72             tmp = tmp + self.generate_noise()
#      73
#      74         return tmp
#
# ~/ML/GD/ML2_lib/loss.py in generate_noise(self)
#      76     def generate_noise(self):
#      77         tmp = additive_noise.Noise(dim=self.d, mean=0, sigma=self.E_var, n=1)
# ---> 78         E = getattr(tmp, self.noise_type)()
#      79
#      80         return E
#
# ~/ML/GD/ML2_lib/additive_noise.py in normal(self)
#      10
#      11     def normal(self):
# ---> 12         rng = np.random.default_rng()
#      13         if self.n == 1:
#      14             return rng.normal(loc=self.mean, scale=self.sigma, size=self.dim)
#
# _generator.pyx in numpy.random._generator.default_rng()
#
# _pcg64.pyx in numpy.random._pcg64.PCG64.__init__()
#
# bit_generator.pyx in numpy.random.bit_generator.BitGenerator.__init__()
#
# bit_generator.pyx in numpy.random.bit_generator.SeedSequence.__init__()
#
# ~/.pyenv/versions/3.8.6/lib/python3.8/random.py in getrandbits(self, k)
#     723         if k <= 0:
#     724             raise ValueError('number of bits must be greater than zero')
# --> 725         numbytes = (k + 7) // 8                       # bits / 8 and rounded up
#     726         x = int.from_bytes(_urandom(numbytes), 'big')
#     727         return x >> (numbytes * 8 - k)                # trim excess bits
#
# KeyboardInterrupt:

# %%
w_init_list = [np.array([0,i]) for i in range(5)]
noise = "student_t"
E_var = 5
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)

# %%
noise = "lognormal"
E_var = 1.75
w_init_list = [np.array([0,i*5]) for i in range(5)]
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)

# %%
w_init_list = [np.array([0,i*5]) for i in range(5)]
noise = "normal"
E_var = 2.2
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)

# %%
w_init_list = [np.array([0,i*5]) for i in range(5)]
noise = "student_t"
E_var = 5
RVSGD_exp.w_init_exp(d=d,trial_num=trial_num,lr=lr,c=c,noise=noise,E_var=E_var,w_init_list=w_init_list,k_list=k_list,n=n)
