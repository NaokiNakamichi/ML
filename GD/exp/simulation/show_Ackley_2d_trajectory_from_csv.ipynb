# %%
import glob
import pandas as pd
from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set
import numpy as np
import datetime
import pickle

# %%
files = glob.glob("remote_exp/remote_save_result/Ackley_2d_trajectory10:21:10:40:06/*")
len(files)
# Out:
# 81

# %%
d = {}
n = 10000
noise = "lognormal"
k_list = [1, 2, 4, 5, 10, 20]
son = loss.Ackley(d=2, noise_type=noise, E_var=1.75)
for file in files:

    content = file.split("/")[-1]
    title = f"{content}"

    with open(file, mode="rb") as f:
        d = pickle.load(f)
    k_core_list,k_selected_index = d["k_core_list"],d["k_selected_index"]
    plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title=title,levels=[2,5,10,15,17,20])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.pyenv/versions/ML2/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     499     try:
# --> 500         fh = fp.fileno()
#     501         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-607619b0b312> in <module>
#      12         d = pickle.load(f)
#      13     k_core_list,k_selected_index = d["k_core_list"],d["k_selected_index"]
# ---> 14     plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
#      15                                                   k_selected_index=k_selected_index, f=son,title=title,levels=[2,5,10,15,17,20])
#      16
#
# ...
