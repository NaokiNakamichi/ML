# %%
import glob
import pandas as pd
from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set
import numpy as np
import datetime
import pickle

# %%
files = glob.glob("remote_exp/remote_save_result/Ackley_2d_total10:20:11:01:49/*")
len(files)
# Out:
# 27

# %%
for file in files:
    df = pd.read_csv(file)
    content = file.split("/")[-1]
    title = f"{content}"
    k_list = [0, 1, 3, 4, 9, 19]
    k_string = [f"{i + 1}" for i in k_list]
    result = df.values

    plot_set.box_plot_k(result, k_list, k_string, title)

# %%
files = glob.glob("remote_exp/remote_save_result/Rosenbrock_2d_grad_noise_student_t10:13:12:38:53/*")
len(files)
# Out:
# 4

# %%
for file in files:
    df = pd.read_csv(file)
    content = file.split("/")[-1]
    title = f"{content}"
    k_list = [0, 1, 3, 4, 9, 19]
    k_string = [f"{i + 1}" for i in k_list]
    result = df.values

    plot_set.box_plot_k(result, k_list, k_string, title)

# %%
files = glob.glob("remote_exp/remote_save_result/Rosenbrock_2d_total10:13:10:29:01/*")
len(files)
# Out:
# 16

# %%
for file in files:
    df = pd.read_csv(file)
    content = file.split("/")[-1]
    title = f"{content}"
    k_list = [0, 1, 3, 4, 9, 19]
    k_string = [f"{i + 1}" for i in k_list]
    result = df.values

    plot_set.box_plot_k(result, k_list, k_string, title)

# %%
print(df.shape)
# Out:
# (100, 6)
