# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.001
noise = "lognormal"
c = 1
w_init = np.array([2, 2])
E_var = 1.75
n = 10000
k_list = [1, 2, 4, 5, 10]
son = loss.RosenBrock(d=d, noise_type=noise, E_var=1.75)

# %%
w_init = np.array([0, 0])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [3.1888389418954093]
# tmp_loss [array([3.18883894])]
# 0
# valid_loss_store [1.0085287212987017, 1.291883863812191]
# tmp_loss [array([1.29188386]), array([1.29188386])]
# 0
# valid_loss_store [1.9226778960013158, 1.0969880253416375, 0.580622643511425, 0.48977813649801266]
# tmp_loss [array([0.48977814]), array([0.48977814]), array([0.48977814]), array([0.48977814])]
# 3
# valid_loss_store [0.5248380761860932, 0.44630351816142677, 0.38381221662715453, 1.478031117265195, 1.1795731226761688]
# tmp_loss [array([1.17957312]), array([1.17957312]), array([1.17957312]), array([1.17957312]), array([1.17957312])]
# 2
# valid_loss_store [0.4049137274091535, 0.7588637091576441, 0.6617748147301036, 0.41326197426799716, 0.576047733420888, 0.48743657289387243, 0.5420256778056486, 0.6362741473788788, 0.6716630998681404, 0.5542388772554913]
# tmp_loss [array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888]), array([0.55423888])]
# 0

# %%
k_w_rv
# Out:
# [array([0.37674586, 0.3092812 ]),
#  array([0.36519238, 0.21118244]),
#  array([0.34842276, 0.14693765]),
#  array([0.514611 , 0.3033225]),
#  array([0.40635557, 0.18803774])]

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 10])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [0.1644592348197935]
# tmp_loss [array([0.16445923])]
# 0
# valid_loss_store [41.13665260868342, 0.27326143023874855]
# tmp_loss [array([0.27326143]), array([0.27326143])]
# 1
# valid_loss_store [0.34793206563715073, 0.2589176679814751, 5.502344497909859, 0.44041339406946983]
# tmp_loss [array([0.44041339]), array([0.44041339]), array([0.44041339]), array([0.44041339])]
# 1
# valid_loss_store [0.5461343406082005, 0.4991116655920167, 0.5230229477581747, 0.7383541450836087, 0.46706401750187976]
# tmp_loss [array([0.46706402]), array([0.46706402]), array([0.46706402]), array([0.46706402]), array([0.46706402])]
# 4
# valid_loss_store [1.2010082635194768, 1.203294007248621, 1.1888551351855687, 1.241867056954013, 1.195519617169242, 1.4463239316623002, 1.3391984748096886, 1.2583977315099497, 1.302730880190179, 1.467461724480007]
# tmp_loss [array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172]), array([1.46746172])]
# 2

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 30])
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [71419.45123355191]
# tmp_loss [array([71419.45123355])]
# 0
# valid_loss_store [40229.11443323394, 40228.745180080114]
# tmp_loss [array([40228.74518008]), array([40228.74518008])]
# 1
# valid_loss_store [29415.78794826678, 25811.555720719753, 18290.379367015157, 29874.431526871012]
# tmp_loss [array([29874.43152687]), array([29874.43152687]), array([29874.43152687]), array([29874.43152687])]
# 2
# valid_loss_store [28669.509786687606, 35783.598539011924, 15119.224263357137, 28478.67137855505, 35280.907710055384]
# tmp_loss [array([35280.90771006]), array([35280.90771006]), array([35280.90771006]), array([35280.90771006]), array([35280.90771006])]
# 2
# valid_loss_store [23477.5967032369, 22858.921197140084, 20323.607804826654, 26726.59281922245, 26771.99553689036, 25233.389197436616, 13285.371772108547, 24094.195649331003, 18553.7564949405, 22744.354626631164]
# tmp_loss [array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663]), array([22744.35462663])]
# 6

# %%
noise = "normal"
son = loss.RosenBrock(d=d, noise_type=noise, E_var=2.2)
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([2, 2])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title="")
# Out:
# valid_loss_store [0.025947258039418764]
# tmp_loss [array([0.02594726])]
# 0
# valid_loss_store [0.036510991905972165, 0.02684883627821505]
# tmp_loss [array([0.02684884]), array([0.02684884])]
# 1
# valid_loss_store [0.056742823859312126, 0.06017720759411784, 0.05135520034902348, 0.05465899153510235]
# tmp_loss [array([0.05465899]), array([0.05465899]), array([0.05465899]), array([0.05465899])]
# 2
# valid_loss_store [0.05145673132936898, 0.06120916779727837, 0.06255486913746076, 0.05755585766730362, 0.0658026012660188]
# tmp_loss [array([0.0658026]), array([0.0658026]), array([0.0658026]), array([0.0658026]), array([0.0658026])]
# 0
# valid_loss_store [0.06701610327247176, 0.07646880131835129, 0.07487518881014701, 0.07255228375576514, 0.07481261420237033, 0.060313547104775475, 0.07073150623059134, 0.08073187542037312, 0.071157015246095, 0.074737088208917]
# tmp_loss [array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709]), array([0.07473709])]
# 5

# %%
# 対数正規分布　ノイズ強
noise = "lognormal"
son = loss.RosenBrock(d=d, noise_type=noise, E_var=1.9)
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([2, 2])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title="")
# Out:
# valid_loss_store [0.9532597599736911]
# tmp_loss [array([0.95325976])]
# 0
# valid_loss_store [1.678543032313938, 0.0854084071652906]
# tmp_loss [array([0.08540841]), array([0.08540841])]
# 1
# valid_loss_store [0.0772382806848647, 0.10249059674633966, 0.2505654523950748, 0.11410709830634409]
# tmp_loss [array([0.1141071]), array([0.1141071]), array([0.1141071]), array([0.1141071])]
# 0
# valid_loss_store [0.09987244933473466, 226.75891817803807, 0.1023308916745238, 0.1374101810471811, 64.1018311108832]
# tmp_loss [array([64.10183111]), array([64.10183111]), array([64.10183111]), array([64.10183111]), array([64.10183111])]
# 0
# valid_loss_store [1.9756947411594739, 0.7800061801788983, 0.1860104795314253, 0.4454923979011345, 0.04673285427002713, 0.19795119712877007, 0.14838563832908422, 0.07664089323579584, 0.07527847553773528, 0.01949459060675955]
# tmp_loss [array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459]), array([0.01949459])]
# 9

# %%
w_init = np.array([0, 5])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [0.4250373168876148]
# tmp_loss [array([0.42503732])]
# 0
# valid_loss_store [1350.450817160367, 0.24962689585703693]
# tmp_loss [array([0.2496269]), array([0.2496269])]
# 1
# valid_loss_store [1.3632106402634379, 2.504999594336666, 0.23301584144352852, 0.27225771084326356]
# tmp_loss [array([0.27225771]), array([0.27225771]), array([0.27225771]), array([0.27225771])]
# 2
# valid_loss_store [0.7413507031445583, 3.6951266493706503, 0.5416111956007332, 7.984721124400806, 1.4985486290513292]
# tmp_loss [array([1.49854863]), array([1.49854863]), array([1.49854863]), array([1.49854863]), array([1.49854863])]
# 2
# valid_loss_store [1.0325621505172573, 0.26894884956906734, 0.440174114644778, 0.9936501550390866, 0.38082261669682194, 2508.376027718902, 0.3495340208990339, 0.41313416026978633, 0.6277499392898087, 0.3341341908243115]
# tmp_loss [array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419]), array([0.33413419])]
# 1

# %%
k_core_list
# Out:
# [array([[[0.        , 5.        ],
#          [0.0078768 , 4.00574831],
#          [0.02244889, 3.20919536],
#          ...,
#          [0.89873047, 0.79678973],
#          [0.89948197, 0.8050493 ],
#          [0.90287068, 0.80854006]]]),
#  array([[[0.00000000e+00, 5.00000000e+00],
#          [7.66751450e-03, 4.00607690e+00],
#          [1.15701799e-02, 3.20860270e+00],
#          ...,
#          [5.49684610e+00, 2.03295536e+01],
#          [5.47509532e+00, 2.03315364e+01],
#          [5.45396714e+00, 2.03334715e+01]],
#
#         [[0.00000000e+00, 5.00000000e+00],
#          [5.41719463e-03, 4.00406330e+00],
#          [2.20914697e-02, 3.20375955e+00],
#          ...,
#          [1.39816677e+00, 2.27294089e+00],
#          [1.58126135e+00, 2.21316638e+00],
#          [1.40017445e+00, 2.27659722e+00]]]),
#  array([[[ 0.00000000e+00,  5.00000000e+00],
#          [-2.55728820e-03,  4.00416766e+00],
#          [ 1.38331138e-03,  3.20920302e+00],
#          ...,
#          [ 7.62767624e-01,  5.76516507e-01],
#          [ 7.59530475e-01,  5.82580764e-01],
#          [ 7.66217072e-01,  5.57240011e-01]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [-4.34622631e-03,  4.00375377e+00],
#          [-2.09533169e-02,  3.20325923e+00],
#          ...,
#          [-1.84894053e-01,  2.43665976e-02],
#          [-1.82554393e-01,  3.23344383e-02],
#          [-1.74598643e-01,  3.45427417e-02]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [ 4.85650522e-03,  4.00044239e+00],
#          [ 2.02634143e-02,  3.20624764e+00],
#          ...,
#          [ 1.42553479e+00,  2.02323394e+00],
#          [ 1.42505302e+00,  2.01807857e+00],
#          [ 1.42290415e+00,  2.02439597e+00]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [ 7.46562381e-03,  4.00582363e+00],
#          [ 2.71056873e-02,  3.20989986e+00],
#          ...,
#          [ 6.91634085e-01,  4.76459837e-01],
#          [ 6.97598259e-01,  4.82598544e-01],
#          [ 7.02590649e-01,  4.84136287e-01]]]),
#  array([[[ 0.00000000e+00,  5.00000000e+00],
#          [ 6.89985171e-03,  3.99394793e+00],
#          [ 2.53844022e-02,  3.20086611e+00],
#          ...,
#          [ 1.44786080e-01,  3.50325571e-02],
#          [ 1.52797416e-01,  3.75028298e-02],
#          [ 1.61061540e-01,  4.05568941e-02]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [ 8.01275559e-03,  4.00259357e+00],
#          [ 2.85824352e-02,  3.20705949e+00],
#          ...,
#          [ 3.17654004e-01,  8.55306617e-02],
#          [ 3.21689930e-01,  9.31627192e-02],
#          [ 3.27731503e-01,  1.00122766e-01]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [-4.45681044e-03,  4.00258455e+00],
#          [-3.73342920e-03,  3.20814210e+00],
#          ...,
#          [ 8.39416693e-01,  7.42770497e-01],
#          [ 8.58371064e-01,  7.41157339e-01],
#          [ 8.54861599e-01,  7.42513793e-01]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [-1.48136587e-02,  4.00432221e+00],
#          [-3.12507774e-02,  3.20918438e+00],
#          ...,
#          [ 5.86585876e-01,  3.36459035e-01],
#          [ 5.78568750e-01,  3.44031999e-01],
#          [ 5.85564898e-01,  3.48209641e-01]],
#
#         [[ 0.00000000e+00,  5.00000000e+00],
#          [-2.75787485e-03,  4.00112325e+00],
#          [ 8.46596975e-04,  3.20684983e+00],
#          ...,
#          [ 1.06158815e-01,  3.69979885e-02],
#          [ 1.14710630e-01,  3.68847781e-02],
#          [ 1.22437961e-01,  3.12519601e-02]]]),
#  array([[[0.        , 5.        ],
#          [0.00803688, 3.99887946],
#          [0.02835474, 3.20364678],
#          ...,
#          [0.18394314, 0.04200413],
#          [0.19224608, 0.04464421],
#          [0.20024897, 0.04825267]],
#
#         [[0.        , 5.        ],
#          [0.00776984, 4.00599168],
#          [0.02825942, 3.20871039],
#          ...,
#          [1.02954801, 1.054075  ],
#          [0.98905504, 1.04153971],
#          [1.01862884, 1.03452682]],
#
#         [[0.        , 5.        ],
#          [0.00785591, 4.00601142],
#          [0.0257642 , 3.20940864],
#          ...,
#          [1.07911247, 1.15889607],
#          [1.08223641, 1.16597019],
#          [1.08586784, 1.1719051 ]],
#
#         ...,
#
#         [[0.        , 5.        ],
#          [0.00719033, 4.00598634],
#          [0.02581583, 3.20717351],
#          ...,
#          [1.14895134, 1.31528637],
#          [1.14931245, 1.32137412],
#          [1.15504097, 1.32688684]],
#
#         [[0.        , 5.        ],
#          [0.00794585, 3.99955813],
#          [0.00733741, 3.18442654],
#          ...,
#          [1.15312446, 1.32297661],
#          [1.15569082, 1.33025302],
#          [1.15859328, 1.33717671]],
#
#         [[0.        , 5.        ],
#          [0.00539612, 4.00533027],
#          [0.02208014, 3.20985747],
#          ...,
#          [0.99027927, 0.97764698],
#          [0.99187927, 0.98431766],
#          [0.98605788, 0.98853104]]])]
