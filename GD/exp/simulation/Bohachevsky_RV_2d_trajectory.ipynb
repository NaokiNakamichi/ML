# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.1
noise = "normal"
c = 1
w_init = np.array([2, 2])
E_var = 1.75
n = 10000
k_list = [1, 2, 4, 5, 10]
son = loss.Bohachevsky(d=d, noise_type=noise, E_var=1.75)

# %%
w_init = np.array([5, 5])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [0.043367617096922606]
# tmp_loss [array([0.04336762])]
# 0
# valid_loss_store [0.011376812949439152, 0.02230760150514277]
# tmp_loss [array([0.0223076]), array([0.0223076])]
# 0
# valid_loss_store [0.04507808883810038, 0.11266309696068888, 0.045155698636460295, 0.0495408097552279]
# tmp_loss [array([0.04954081]), array([0.04954081]), array([0.04954081]), array([0.04954081])]
# 0
# valid_loss_store [0.042641050986439666, 0.13498497018914157, 0.13011628052173085, 0.09602371804955112, 0.006738391705685465]
# tmp_loss [array([0.00673839]), array([0.00673839]), array([0.00673839]), array([0.00673839]), array([0.00673839])]
# 4
# valid_loss_store [0.23962975863775954, 0.02523497901324856, 0.023530964790360764, 0.12140490349665667, 0.19359137241572433, 0.030756186433953614, 0.007285891066765915, 0.18273218554326587, 0.018572121969380184, 0.20896495326803877]
# tmp_loss [array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495]), array([0.20896495])]
# 6

# %%
k_w_rv
# Out:
# [array([-0.00095252, -0.03622348]),
#  array([ 0.02532865, -0.00814837]),
#  array([0.03858954, 0.026833  ]),
#  array([0.02010727, 0.00535668]),
#  array([-0.00244838,  0.01466179])]

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 10])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [4.106904269003851]
# tmp_loss [array([4.10690427])]
# 0
# valid_loss_store [6.329597649113594, 6.180709022620464]
# tmp_loss [array([6.18070902]), array([6.18070902])]
# 1
# valid_loss_store [11.927160441131994, 11.851749893282669, 11.905881968240898, 11.88373204657787]
# tmp_loss [array([11.88373205]), array([11.88373205]), array([11.88373205]), array([11.88373205])]
# 1
# valid_loss_store [16.360926256212995, 16.316311728025216, 16.47399306527673, 16.169557010740295, 16.26425344521433]
# tmp_loss [array([16.26425345]), array([16.26425345]), array([16.26425345]), array([16.26425345]), array([16.26425345])]
# 3
# valid_loss_store [39.38595599411879, 39.898160429528915, 39.34873480720673, 39.76217579529841, 39.71293166919128, 39.71751471286448, 39.92915566435311, 39.55902273719616, 39.608222736616646, 40.25083798043294]
# tmp_loss [array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798]), array([40.25083798])]
# 2

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 30])
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [10.923711973777538]
# tmp_loss [array([10.92371197])]
# 0
# valid_loss_store [25.75315540735503, 25.798852754695275]
# tmp_loss [array([25.79885275]), array([25.79885275])]
# 0
# valid_loss_store [78.62001528177247, 78.16473558837355, 77.7700103007972, 78.05318173576863]
# tmp_loss [array([78.05318174]), array([78.05318174]), array([78.05318174]), array([78.05318174])]
# 2
# valid_loss_store [113.80679043089327, 114.60333291205026, 113.18628644384691, 114.23271415542337, 114.08837772387737]
# tmp_loss [array([114.08837772]), array([114.08837772]), array([114.08837772]), array([114.08837772]), array([114.08837772])]
# 2
# valid_loss_store [339.9826857043608, 340.7870100510029, 339.0421025700447, 339.30851045177076, 339.40793688223164, 338.9488330966741, 339.71844833080894, 340.7554180442699, 339.36480781454617, 338.677890777213]
# tmp_loss [array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078]), array([338.67789078])]
# 9
