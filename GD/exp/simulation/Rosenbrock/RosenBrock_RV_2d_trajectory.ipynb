# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.0007
noise = "lognormal"
c = 1
w_init = np.array([3, 3])
E_var = 2
n = 10000
k_list = [1, 2, 4, 5, 10]
son = loss.RosenBrock(d=d, noise_type=noise, E_var=1.75)

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [116.60866416099297]
# tmp_loss [array([116.60866416])]
# 0
# valid_loss_store [9.057726760127427, 6.689352308202958]
# tmp_loss [array([6.68935231]), array([6.68935231])]
# 1
# valid_loss_store [7.121368039628071, 7.043846336453534, 6.9009817564760905, 6.578618952854918]
# tmp_loss [array([6.57861895]), array([6.57861895]), array([6.57861895]), array([6.57861895])]
# 3
# valid_loss_store [7.463061008361771, 7.240506760612663, 7.222165107934746, 7.233242619250303, 7.071208326622196]
# tmp_loss [array([7.07120833]), array([7.07120833]), array([7.07120833]), array([7.07120833]), array([7.07120833])]
# 4
# valid_loss_store [7.769467742417962, 7.565046468631704, 8.01680526510332, 8.547913484657492, 7.659806105513271, 7.215706595102, 9.096841683083372, 7.890916979476282, 7.701944684846386, 7.824027935160415]
# tmp_loss [array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794]), array([7.82402794])]
# 5

# %%
k_w_rv
# Out:
# [array([1.14045263, 1.32368789]),
#  array([1.12749996, 1.2867383 ]),
#  array([1.0678556 , 1.15894845]),
#  array([1.06735518, 1.16038445]),
#  array([1.10129466, 1.22433449])]

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 10])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [0.35666014061142004]
# tmp_loss [array([0.35666014])]
# 0
# valid_loss_store [0.2088808746915513, 0.2780831180183377]
# tmp_loss [array([0.27808312]), array([0.27808312])]
# 0
# valid_loss_store [0.42643302932038074, 0.37404751847181195, 0.2425226588400276, 24729.579488904517]
# tmp_loss [array([24729.5794889]), array([24729.5794889]), array([24729.5794889]), array([24729.5794889])]
# 2
# valid_loss_store [0.4831952630610611, 0.7262850022924637, 5.869871728850923, 0.5198179105350393, 0.5556023083730506]
# tmp_loss [array([0.55560231]), array([0.55560231]), array([0.55560231]), array([0.55560231]), array([0.55560231])]
# 0
# valid_loss_store [1.2496519536664612, 330.4972718979638, 9.4238048625683, 1.409167328335193, 1.3129065910820035, 1.3339240128767884, 1.3067646051123682, 1.3649911386538163, 1.2710595292194622, 1.3903115624431177]
# tmp_loss [array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156]), array([1.39031156])]
# 0

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 30])
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [59464.30956981211]
# tmp_loss [array([59464.30956981])]
# 0
# valid_loss_store [48614.30780116179, 36738.714096508156]
# tmp_loss [array([36738.71409651]), array([36738.71409651])]
# 1
# valid_loss_store [32675.643621387433, 29949.0236762322, 25826.432929555216, 32446.62309742354]
# tmp_loss [array([32446.62309742]), array([32446.62309742]), array([32446.62309742]), array([32446.62309742])]
# 2
# valid_loss_store [27730.519929851234, 28626.783792088816, 19278.437753465812, 36533.42430397828, 32445.930679546906]
# tmp_loss [array([32445.93067955]), array([32445.93067955]), array([32445.93067955]), array([32445.93067955]), array([32445.93067955])]
# 2
# valid_loss_store [26638.124977811458, 19691.883324256534, 21271.383479961703, 20128.782778158584, 21870.269864688686, 21129.91855214859, 19736.14114901964, 12274.469164756187, 20508.383395192617, 25077.804980973255]
# tmp_loss [array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097]), array([25077.80498097])]
# 7

# %%
noise = "normal"
son = loss.RosenBrock(d=d, noise_type=noise, E_var=2.2)
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([2, 2])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title="")
# Out:
# valid_loss_store [0.0228191785864567]
# tmp_loss [array([0.02281918])]
# 0
# valid_loss_store [0.045394673000844224, 0.0505157876241349]
# tmp_loss [array([0.05051579]), array([0.05051579])]
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-b5e12fe7a981> in <module>
#       3 RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
#       4 w_init = np.array([2, 2])
# ----> 5 k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
#       6 plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
#       7                                                   k_selected_index=k_selected_index, f=son,title="")
#
# ~/ML2/GD/ML2_lib/RV_SGDAve.py in k_all_transition(self, k_list, w_init)
#     561
#     562         for k in k_list:
# --> 563             core_store, selected_index, w_rv = self.all_transition(k, w_init)
#     564             k_core_list.append(core_store)
#     565             k_selected_index.append(selected_index)
#
# ~/ML2/GD/ML2_lib/RV_SGDAve.py in all_transition(self, k, w_init)
#     516         f_transition = []
#     517         selected_index = 0
# --> 518         _, core_store = self.learn(k, w_init)
#     519
#     520         core_store = np.array(core_store)
#
# ~/ML2/GD/ML2_lib/RV_SGDAve.py in learn(self, k, w_init)
#     450             core = algo_sgd.SGD(w_init=w_init, a=self.lr, t_max=core_num - 1, fixed_lr=self.fixed_lr)
#     451             for _ in core:
# --> 452                 core.update(self.model_opt)
#     453             core_store.append(core.wstore)
#     454             model_store.append(np.mean(core.wstore, axis=0))
#
# ~/ML2/GD/ML2_lib/algo_sgd.py in update(self, model)
#      43                     self.w = self.w - self.a * grad
#      44         else:
# ---> 45             grad = model.g_opt(w=self.w)
#      46             if 100000000 < np.sum(grad ** 2):
#      47                 grad *= 0.001
#
# ~/ML2/GD/ML2_lib/loss.py in g_opt(self, w)
#     100                 tmp[i] = 100 * (-4) * w[i] * (w[i + 1] - w[i] ** 2) + 2 * (w[i] - 1)
#     101             elif i == self.d - 1:
# --> 102                 tmp[i] = 100 * 2 * (w[i] - w[i - 1] ** 2)
#     103             else:
#     104                 tmp[i] = 100 * (-4) * w[i] * (w[i + 1] - w[i] ** 2) + 2 * (w[i] - 1) + 100 * 2 * (w[i] - w[i - 1] ** 2)
#
# KeyboardInterrupt:

# %%
# 対数正規分布　ノイズ強
noise = "lognormal"
son = loss.RosenBrock(d=d, noise_type=noise, E_var=1.9)
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([2, 2])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son,title="")

# %%
w_init = np.array([0, 5])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)

# %%
k_core_list
