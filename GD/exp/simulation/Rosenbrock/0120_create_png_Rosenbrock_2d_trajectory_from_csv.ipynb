# %%
import glob
import pandas as pd
from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set
import numpy as np
import datetime
import pickle

# %%
files = glob.glob("../remote_exp/remote_save_result/Rosenbrock_2d_trajectory01:20:13:10:28/*")
len(files)
# Out:
# 150

# %%
d = {}
n = 10000
noise = "lognormal"
k_list = [1, 2, 4, 5, 10, 20]
son = loss.RosenBrock(d=2, noise_type=noise, E_var=1.75)
for file in files:

    content = file.split("/")[-1]
    title = f"{content}"

    now = "0210"

    if "_2_2" in title and "lognormal" in title and "1.9" in title:


        print(title)

        with open(file, mode="rb") as f:
            d = pickle.load(f)
        k_core_list,k_selected_index = d["k_core_list"],d["k_selected_index"]
        plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                      k_selected_index=k_selected_index, f=son,title=title, folder_title=f"result_png/trajectory/{now}",saving_png=True)
# Out:
# RVSGD_Rosenbrock_trajectory_noise_lognormal_D_2_sample_num10000_noise_va_1.9_w_init_2_2f_noiselognormalf_noise_E1.75.pickle
# RVSGD_Rosenbrock_trajectory_noise_normal_D_2_sample_num10000_noise_va_1.9_w_init_2_2f_noiselognormalf_noise_E1.75.pickle

# %%
title in "-4"
# Out:
# False

# %%
"-4" not in title
# Out:
# True
