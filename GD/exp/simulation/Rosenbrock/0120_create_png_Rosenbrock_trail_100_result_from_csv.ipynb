# %%
import glob
import pandas as pd
from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set
import numpy as np
import datetime
import pickle
import os

# %%
# files = glob.glob("../remote_exp/remote_save_result/Rosenbrock_2d_total01:22:20:00:47/*")
files = glob.glob("../remote_exp/remote_save_result/Rosenbrock_2d_total01:20:13:11:05/*")
len(files)
# Out:
# 75

# %%
for file in files:
    df = pd.read_csv(file)
    content = file.split("/")[-1]
    file_name = f"{content}"
    title = "100 trials excess risk"

    now = "0123"

    if "4" not in file_name and "_2_2" in file_name:


        print(df.describe())
        print(file_name)
        k_list = [0, 1, 3, 4, 9, 19]
        k_string = [f"{i + 1}" for i in k_list]
        result = df.values

        plot_set.box_plot_k(result, k_list, k_string, title, folder_title=f"result_png/100trials/{now}", saving_png=False,file_name=file_name,outliers=False)
# Out:
#                 1           2           4           5          10          20
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.027031    0.033590    0.043580    0.048035    0.058184    0.078311
# std      0.009705    0.008441    0.007802    0.007144    0.005137    0.004978
# min      0.008686    0.017519    0.018234    0.026145    0.042203    0.066594
# 25%      0.020030    0.026859    0.038617    0.043399    0.055307    0.075829
# 50%      0.026472    0.033588    0.043620    0.048831    0.058652    0.078965
# 75%      0.033782    0.038702    0.049294    0.052503    0.061417    0.081586
# max      0.054273    0.054559    0.059424    0.067209    0.068862    0.087542
# noise_lognormal_Evar1.2_trial_num_100_D2_sample_num10000_RV_w_init_2_2_f_noiselognormal_f_noise_E1.75_lr0.001_n_10000.csv
#                   1           2           4           5          10  \
# count    100.000000  100.000000  100.000000  100.000000  100.000000
# mean     413.178679    0.095400    0.045807    0.043423    0.041971
# std     3534.014508    0.084648    0.024859    0.018476    0.014354
# min        0.023518    0.010486    0.005250    0.005607    0.009644
# 25%        0.082932    0.046521    0.029410    0.031911    0.032821
# 50%        0.186195    0.077562    0.041560    0.042789    0.040909
# 75%        0.912440    0.113418    0.058551    0.055339    0.051373
# max    34836.842293    0.473792    0.150716    0.087219    0.090397
#
#                20
# count  100.000000
# mean     0.051751
# std      0.013716
# min      0.013757
# 25%      0.044837
# 50%      0.051551
# 75%      0.060901
# max      0.080814
# noise_lognormal_Evar1.75_trial_num_100_D2_sample_num10000_RV_w_init_2_2_f_noiselognormal_f_noise_E1.75_lr0.001_n_10000.csv
#                   1           2           4           5          10  \
# count    100.000000  100.000000  100.000000  100.000000  100.000000
# mean    1199.008345    1.443179    0.079874    0.066713    0.046277
# std     5385.848535    6.113497    0.039197    0.035848    0.018231
# min        0.038631    0.019020    0.014376    0.010083    0.012074
# 25%        0.264270    0.111193    0.050003    0.038435    0.032932
# 50%        0.876108    0.160473    0.073508    0.062352    0.044060
# 75%        5.587228    0.397847    0.102747    0.090979    0.059737
# max    40883.878008   56.834771    0.200493    0.163148    0.092252
#
#                20
# count  100.000000
# mean     0.053210
# std      0.016494
# min      0.021387
# 25%      0.042426
# 50%      0.053296
# 75%      0.064478
# max      0.100124
# noise_lognormal_Evar1.9_trial_num_100_D2_sample_num10000_RV_w_init_2_2_f_noiselognormal_f_noise_E1.75_lr0.001_n_10000.csv
