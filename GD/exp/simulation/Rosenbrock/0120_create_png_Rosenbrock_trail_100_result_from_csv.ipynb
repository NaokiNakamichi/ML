# %%
import glob
import pandas as pd
from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set
import numpy as np
import datetime
import pickle
import os

# %%
files = glob.glob("../remote_exp/remote_save_result/Rosenbrock_2d_total01:22:20:00:47/*")
len(files)
# Out:
# 1

# %%
for file in files:
    df = pd.read_csv(file)
    content = file.split("/")[-1]
    file_name = f"{content}"
    title = "100 trials excess risk"

    now = "0123"

    if "4" not in file_name:


        print(df.describe())
        print(file_name)
        k_list = [0, 1, 3, 4, 9, 19]
        k_string = [f"{i + 1}" for i in k_list]
        result = df.values

        plot_set.box_plot_k(result, k_list, k_string, title, folder_title=f"result_png/100trials/{now}", saving_png=True,file_name=file_name,outliers=False)
# Out:
#                 2           3           5           6          11          21
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     7.284621    6.526616    6.785597    6.998142    7.449704    8.312609
# std      3.138708    0.285785    0.511214    0.302804    0.215455    0.303326
# min      5.736883    5.488547    2.357141    5.171078    6.699684    6.249782
# 25%      6.429564    6.379378    6.681560    6.912033    7.369803    8.184897
# 50%      6.593017    6.580094    6.854000    7.040551    7.503155    8.396341
# 75%      6.880616    6.697077    6.998320    7.197514    7.594628    8.494164
# max     32.220147    7.407008    7.268139    7.386658    7.753161    8.639056
# noise_lognormal_Evar1.75_trial_num_100_D2_sample_num10000_RV_w_init_3_3_f_noisenormal_f_noise_E1.75_lr0.0007_n_10000.csv
