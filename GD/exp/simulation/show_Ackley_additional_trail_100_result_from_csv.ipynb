# %%
import glob
import pandas as pd
from ML2_lib import RV_SGDAve
from ML2_lib import loss
from ML2_lib import plot_set
import numpy as np
import datetime
import pickle
import os

# %%
files = glob.glob("remote_exp/remote_save_result/Ackley_2d_total_additional_w_init10:27:11:40:22/*")
len(files)
# Out:
# 24

# %%
folder_title = "Ackley_additional_w_init"
now = datetime.datetime.now()
new_dir_path_recursive = f"save_result_data/{folder_title}box_plot_image_{now:%m:%d:%H:%M:%S}"
os.makedirs(new_dir_path_recursive, exist_ok=True)


for file in files:
    df = pd.read_csv(file)
    content = file.split("/")[-1]
    title = f"{content}"
    k_list = [0, 1, 3, 4, 9, 19]
    k_string = [f"{i + 1}" for i in k_list]
    result = df.values

    plot_set.box_plot_k(result, k_list, k_string, title=title,folder_title=new_dir_path_recursive,saving_png=True)
