# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RVSGD_exp

# %%
d = 2
trial_num = 100
lr = 0.1
noise = "lognormal"
c = 1
w_init = np.array([5, 5])
E_var = 0.7
n = 10000
k_list = [0, 1, 3, 4, 9, 19]
son = loss.Ackley(d=d, noise_type=noise, E_var=E_var)

# %%
title = f"RVSGD_Ackley_trajectory_noise_{noise}_D_{d}_sample_num{n}_noise_va_{E_var}_w_init_{w_init[0]}_{w_init[1]}"
folder_title = "Ackley_"
RVSGD_exp.easy_exp(trial_num=trial_num, lr=lr, c=c, w_init=w_init, k_list=k_list, son=son, n=n,title=title,folder_title=folder_title)
