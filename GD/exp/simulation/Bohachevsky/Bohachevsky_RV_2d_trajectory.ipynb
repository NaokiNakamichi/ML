# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from ML2_lib import loss
from ML2_lib import plot_set
from ML2_lib import RV_SGDAve

# %%
d = 2
trial_num = 100
lr = 0.1
noise = "lognormal"
c = 1
w_init = np.array([2, 2])
E_var = 1.75
n = 10000
k_list = [1, 2, 4, 5, 10]
son = loss.Bohachevsky(d=d, noise_type=noise, E_var=1.75)

# %%
w_init = np.array([5, 5])
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=lr)
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [0.48569045849603804]
# tmp_loss [array([0.48569046])]
# 0
# valid_loss_store [0.5311757390474648, 0.15048301637516426]
# tmp_loss [array([0.15048302]), array([0.15048302])]
# 1
# valid_loss_store [0.3629909910369194, 0.6188706758289971, 0.8356679036167111, 0.5830152358247895]
# tmp_loss [array([0.58301524]), array([0.58301524]), array([0.58301524]), array([0.58301524])]
# 0
# valid_loss_store [1.052139939863198, 1.553700829610502, 0.4943416460616937, 0.778411987244382, 0.9006908654015366]
# tmp_loss [array([0.90069087]), array([0.90069087]), array([0.90069087]), array([0.90069087]), array([0.90069087])]
# 2
# valid_loss_store [0.7053128162833757, 0.9173309369717957, 1.5663637606014158, 1.1571837782315448, 0.8498624217816686, 0.643431208625812, 1.4768271213893298, 0.0781922448108856, 1.0790456019154226, 0.8783286144838112]
# tmp_loss [array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861]), array([0.87832861])]
# 7

# %%
k_w_rv
# Out:
# [array([ 0.02120419, -0.0158792 ]),
#  array([-0.00948501,  0.0107609 ]),
#  array([0.03213353, 0.01348534]),
#  array([-0.01202845,  0.001659  ]),
#  array([0.013375  , 0.02163084])]

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.001)
w_init = np.array([0, 10])
k_core_list, k_selected_index, _ = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [4.114314532385317]
# tmp_loss [array([4.11431453])]
# 0
# valid_loss_store [6.151663737434546, 6.279069697880772]
# tmp_loss [array([6.2790697]), array([6.2790697])]
# 0
# valid_loss_store [11.864507226139922, 11.981465411741217, 12.01674970397143, 11.90651058569218]
# tmp_loss [array([11.90651059]), array([11.90651059]), array([11.90651059]), array([11.90651059])]
# 0
# valid_loss_store [16.271535095543037, 16.321830863953718, 16.01135347708811, 16.31956304669985, 16.513088064649367]
# tmp_loss [array([16.51308806]), array([16.51308806]), array([16.51308806]), array([16.51308806]), array([16.51308806])]
# 2
# valid_loss_store [39.64816069587563, 39.48646096267245, 39.61805238511015, 39.55844788865643, 39.414760734013804, 39.96081390544355, 39.63673458281166, 39.812793428006074, 39.71448918102148, 39.58544015620169]
# tmp_loss [array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016]), array([39.58544016])]
# 4

# %%
RV = RV_SGDAve.RVSGDByW(model_opt=son, c=1, n=n, lr=0.1)
w_init = np.array([30, 30])
k_core_list, k_selected_index, k_w_rv = RV.k_all_transition(k_list=k_list, w_init=w_init)
plot_set.multiple_w_value_2d_k_candidates_contour(k_list=k_list, k_list_core_store=k_core_list, _t_max=n,
                                                  k_selected_index=k_selected_index, f=son)
# Out:
# valid_loss_store [0.058424664443427865]
# tmp_loss [array([0.05842466])]
# 0
# valid_loss_store [0.4626118389889662, 0.23632218718771636]
# tmp_loss [array([0.23632219]), array([0.23632219])]
# 1
# valid_loss_store [0.7525627944662333, 0.599792488506405, 1.143744448515581, 1.1651021706855726]
# tmp_loss [array([1.16510217]), array([1.16510217]), array([1.16510217]), array([1.16510217])]
# 1
# valid_loss_store [0.29777337560281264, 1.190687035155034, 0.2922020416744307, 0.5372715076587455, 0.7982337774702347]
# tmp_loss [array([0.79823378]), array([0.79823378]), array([0.79823378]), array([0.79823378]), array([0.79823378])]
# 2
# valid_loss_store [2.550932242587079, 1.1132698404486785, 1.4883728892900128, 0.5216569306042403, 0.3669969935581965, 1.9274347145148518, 1.937652083613586, 0.8406153850225421, 1.3793165504846037, 1.4647538987984456]
# tmp_loss [array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539]), array([1.4647539])]
# 4
